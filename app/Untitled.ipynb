# %%
import requests

headers = {
    'Authorization': '8cac7813-d42e-4372-8a7e-4d1b3d4b9a78'
}

response = requests.get('https://api.vesseltracker.com/api/v1/vessels/userpolygon?timeUpdated=2021-08-24T12%3a55%3a35%2b0000', headers=headers)

# %%
type(response)
# Out:
# requests.models.Response

# %%
import json

json_data = json.loads(response.text)

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
data_list = json_data['vessels']

# %%
data_list
# Out:
# [{'aisStatic': {'name': 'JIN NING 16',
#    'mmsi': 413459820,
#    'imo': 9211133,
#    'callsign': 'BQWB',
#    'flag': 'China',
#    'dimA': 166,
#    'dimB': 23,
#    'dimC': 16,
#    'dimD': 16,
#    'length': 189.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2020-11-01T14:01:26Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:49:54Z',
#    'eta': '2021-08-24T14:30:00Z',
#    'dest': 'TAICANG',
#    'draught': 10.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:36Z',
#    'src': 'T-AIS',
#    'lon': 122.57749333333334,
#    'lat': 31.136073333333332,
#    'sog': 0.4,
#    'cog': 349.2,
#    'hdg': 59.0,
#    'rot': 0,
#    'navStatus': 1},
#   'voyageDetails': {'destination': 'Taicang',
#    'locode': 'CNTAG',
#    'portCountry': 'China'},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-24T10:23:29Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'BTG MATTERHORN',
#    'mmsi': 311000427,
#    'imo': 9731822,
#    'callsign': 'C6CB7',
#    'flag': 'Bahamas',
#    'dimA': 196,
#    'dimB': 33,
#    'dimC': 19,
#    'dimD': 13,
#    'length': 229.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-05T05:19:06Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T10:17:27Z',
#    'eta': '2021-08-11T14:00:00Z',
#    'dest': 'CN MCH>CN JIA',
#    'draught': 9.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:36Z',
#    'src': 'T-AIS',
#    'lon': 122.62746833333334,
#    'lat': 31.172165,
#    'sog': 0.2,
#    'cog': 48.0,
#    'hdg': 62.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-11T01:26:25Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'XIN SHI JI 29',
#    'mmsi': 701135000,
#    'imo': 9883302,
#    'callsign': 'LW3726',
#    'flag': 'Argentina',
#    'dimA': 35,
#    'dimB': 35,
#    'dimC': 8,
#    'dimD': 3,
#    'length': 70.0,
#    'width': 11.0,
#    'typeOfShipAndCargo': 30,
#    'aisShiptype': 'fishing_boats',
#    'updateTime': '2020-01-04T21:29:08Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:55:38Z',
#    'eta': '2021-12-06T10:00:00Z',
#    'dest': 'PTO BUENOS AIRES',
#    'draught': 5.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:27Z',
#    'src': 'T-AIS',
#    'lon': -58.37258,
#    'lat': -34.57833333333333,
#    'sog': 0.0,
#    'cog': 309.0,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 5},
#   'voyageDetails': {'destination': 'Buenos Aires',
#    'locode': 'ARBUE',
#    'portCountry': 'Argentina'},
#   'geoDetails': {'currentPort': 'Buenos Aires',
#    'currentPortLocode': 'ARBUE',
#    'currentBerth': 'Terbasa (Grain Terminal)',
#    'timeOfATChange': '2021-08-11T12:09:33Z',
#    'status': 'moored',
#    'portCountry': 'Argentina'}},
#  {'aisStatic': {'name': 'BURN RATE',
#    'mmsi': 339544000,
#    'imo': 1008891,
#    'callsign': '6YSX8',
#    'flag': 'Jamaica',
#    'dimA': 22,
#    'dimB': 15,
#    'dimC': 9,
#    'dimD': 0,
#    'length': 37.0,
#    'width': 9.0,
#    'typeOfShipAndCargo': 37,
#    'aisShiptype': 'pleasure_crafts',
#    'updateTime': '2019-11-08T14:48:37Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:55:18Z',
#    'eta': '2021-08-23T19:00:00Z',
#    'dest': 'ST THOMAS',
#    'draught': 2.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:30Z',
#    'src': 'S-AIS',
#    'lon': -64.92036666666667,
#    'lat': 18.335583333333332,
#    'sog': 102.3,
#    'cog': 360.0,
#    'hdg': 225.0,
#    'rot': 11,
#    'navStatus': 1},
#   'geoDetails': {'timeOfATChange': '2021-04-23T15:58:12Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'YUAN JU WAN',
#    'mmsi': 414489000,
#    'imo': 9845958,
#    'callsign': 'BONH2',
#    'flag': 'China',
#    'dimA': 202,
#    'dimB': 48,
#    'dimC': 5,
#    'dimD': 39,
#    'length': 250.0,
#    'width': 44.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2021-06-18T19:51:03Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-19T14:23:19Z',
#    'eta': '2021-09-18T15:00:00Z',
#    'dest': 'ROTTERDAM NETHERLAND',
#    'draught': 14.6,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:47Z',
#    'src': 'T-AIS',
#    'lon': 80.229175,
#    'lat': 5.7961583333333335,
#    'sog': 11.7,
#    'cog': 276.7,
#    'hdg': 278.0,
#    'rot': 8,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Rotterdam',
#    'locode': 'NLRTM',
#    'portCountry': 'Netherlands'},
#   'geoDetails': {'timeOfATChange': '2021-08-18T23:52:47Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'DESERT RHAPSODY',
#    'mmsi': 538002382,
#    'imo': 9321005,
#    'callsign': 'V7II2',
#    'flag': 'Marshall Islands',
#    'dimA': 156,
#    'dimB': 34,
#    'dimC': 13,
#    'dimD': 19,
#    'length': 190.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-07-03T15:08:45Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:39:49Z',
#    'eta': '2021-08-16T21:00:00Z',
#    'dest': 'US MSY',
#    'draught': 7.6,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:48Z',
#    'src': 'T-AIS',
#    'lon': -89.998495,
#    'lat': 29.941328333333335,
#    'sog': 0.0,
#    'cog': 318.6,
#    'hdg': 311.0,
#    'rot': 0,
#    'navStatus': 5},
#   'voyageDetails': {'destination': 'New Orleans',
#    'locode': 'USMSY',
#    'portCountry': 'United States of America'},
#   'geoDetails': {'currentPort': 'New Orleans',
#    'currentPortLocode': 'USMSY',
#    'timeOfATChange': '2021-08-22T02:10:37Z',
#    'status': 'moored',
#    'portCountry': 'United States of America'}},
#  {'aisStatic': {'name': 'BREB XIAN',
#    'mmsi': 209452000,
#    'imo': 9155418,
#    'callsign': 'P3EH8',
#    'flag': 'Cyprus',
#    'dimA': 86,
#    'dimB': 14,
#    'dimC': 6,
#    'dimD': 10,
#    'length': 100.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-06-27T14:43:43Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:52:05Z',
#    'eta': '2021-08-25T06:00:00Z',
#    'dest': 'MUKRAN',
#    'draught': 5.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:50Z',
#    'src': 'T-AIS',
#    'lon': 18.380845,
#    'lat': 54.9637,
#    'sog': 11.2,
#    'cog': 270.0,
#    'hdg': 270.0,
#    'rot': -127,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Mukran',
#    'locode': 'DEMUK',
#    'portCountry': 'Germany'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T07:08:01Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'ALFA 007',
#    'mmsi': 735058741,
#    'imo': 9182095,
#    'callsign': 'HC5107',
#    'flag': 'Ecuador',
#    'dimA': 84,
#    'dimB': 23,
#    'dimC': 5,
#    'dimD': 11,
#    'length': 107.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-01-02T20:57:38Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T01:40:13Z',
#    'eta': '2021-06-18T16:00:00Z',
#    'dest': 'LA LIB ECU',
#    'draught': 4.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:37Z',
#    'src': 'S-AIS',
#    'lon': -80.91134,
#    'lat': -2.1633566666666666,
#    'sog': 0.1,
#    'cog': 360.0,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 5},
#   'voyageDetails': {'destination': 'Los Angeles / Long Beach',
#    'portCountry': 'United States of America'},
#   'geoDetails': {'currentAnchorage': 'Punta Blanca Ecuador',
#    'timeOfATChange': '2021-08-23T20:58:36Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'FAIRCHEM ENDURANCE',
#    'mmsi': 372916000,
#    'imo': 9800441,
#    'callsign': '3FXJ6',
#    'flag': 'Panama',
#    'dimA': 129,
#    'dimB': 30,
#    'dimC': 17,
#    'dimD': 10,
#    'length': 159.0,
#    'width': 27.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-09-23T16:12:42Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T05:45:42Z',
#    'eta': '2021-08-22T22:00:00Z',
#    'dest': 'KR USN',
#    'draught': 6.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:52Z',
#    'src': 'T-AIS',
#    'lon': 129.57497833333332,
#    'lat': 35.116526666666665,
#    'sog': 4.6,
#    'cog': 331.0,
#    'hdg': 337.0,
#    'rot': 127,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Ulsan',
#    'locode': 'KRUSN',
#    'portCountry': 'South Korea'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T09:41:18Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'CREST CENTURION 2',
#    'mmsi': 566472000,
#    'imo': 9756640,
#    'callsign': '9V2839',
#    'flag': 'Singapore',
#    'dimA': 32,
#    'dimB': 53,
#    'dimC': 13,
#    'dimD': 10,
#    'length': 85.0,
#    'width': 23.0,
#    'typeOfShipAndCargo': 90,
#    'aisShiptype': 'others',
#    'updateTime': '2020-10-16T11:08:33Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:55:54Z',
#    'eta': '2021-08-09T05:00:00Z',
#    'dest': 'AMPA 25',
#    'draught': 6.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:55Z',
#    'src': 'T-AIS',
#    'lon': 114.18154833333334,
#    'lat': 4.662438333333333,
#    'sog': 0.0,
#    'cog': 337.1,
#    'hdg': 279.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:55:55Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'ALICE',
#    'mmsi': 511487000,
#    'imo': 8927979,
#    'callsign': 'T8A2571',
#    'flag': 'Palau',
#    'dimA': 112,
#    'dimB': 26,
#    'dimC': 12,
#    'dimD': 4,
#    'length': 138.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-08-24T12:55:57Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:37:04Z',
#    'eta': '2021-08-27T08:00:00Z',
#    'dest': 'YEISK',
#    'draught': 3.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:57Z',
#    'src': 'T-AIS',
#    'lon': 39.665205,
#    'lat': 41.112201666666664,
#    'sog': 6.1,
#    'cog': 329.8,
#    'hdg': 327.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-24T11:39:36Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'CAPO NOLI',
#    'mmsi': 247336300,
#    'imo': 9540390,
#    'callsign': 'IIXS2',
#    'flag': 'Italy',
#    'dimA': 15,
#    'dimB': 16,
#    'dimC': 6,
#    'dimD': 5,
#    'length': 31.0,
#    'width': 11.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2017-12-08T04:58:52Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:51:57Z',
#    'eta': '2021-08-08T12:00:00Z',
#    'dest': 'SAVONA',
#    'draught': 5.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:59Z',
#    'src': 'T-AIS',
#    'lon': 8.489273333333333,
#    'lat': 44.30909166666667,
#    'sog': 0.0,
#    'cog': 297.7,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Savona',
#    'locode': 'ITSVN',
#    'portCountry': 'Italy'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:52:50Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'ALHANI',
#    'mmsi': 642122020,
#    'imo': 9331153,
#    'callsign': '5AXF',
#    'flag': 'Libya',
#    'dimA': 208,
#    'dimB': 41,
#    'dimC': 20,
#    'dimD': 24,
#    'length': 249.0,
#    'width': 44.0,
#    'typeOfShipAndCargo': 83,
#    'aisShiptype': 'tankships',
#    'updateTime': '2021-08-11T09:29:05Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-15T02:29:10Z',
#    'eta': '2021-08-30T07:00:00Z',
#    'dest': 'USGC FOR ORDERS',
#    'draught': 13.7,
#    'source': 'T-AIS',
#    'cargotype': 3},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:45Z',
#    'src': 'S-AIS',
#    'lon': -62.289251666666665,
#    'lat': 37.253465,
#    'sog': 10.8,
#    'cog': 240.6,
#    'hdg': 239.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-13T10:06:38Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'PANDA',
#    'mmsi': 273358350,
#    'imo': 9614024,
#    'callsign': 'UBEI7',
#    'flag': 'Russia',
#    'dimA': 16,
#    'dimB': 15,
#    'dimC': 2,
#    'dimD': 10,
#    'length': 31.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2020-02-25T00:22:42Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T09:33:38Z',
#    'eta': '2021-06-03T03:00:00Z',
#    'dest': 'VYP/KOZMINO',
#    'draught': 4.5,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:02Z',
#    'src': 'T-AIS',
#    'lon': 133.00938333333335,
#    'lat': 42.71483333333333,
#    'sog': 0.0,
#    'cog': 67.0,
#    'hdg': 313.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Kozmino',
#    'locode': 'RUKZM',
#    'portCountry': 'Russia'},
#   'geoDetails': {'currentPort': 'Kozmino',
#    'currentPortLocode': 'RUKZM',
#    'currentBerth': 'Kozmino Oil Terminal',
#    'timeOfATChange': '2021-08-24T07:43:31Z',
#    'status': 'moored',
#    'portCountry': 'Russia'}},
#  {'aisStatic': {'name': 'THEMIS',
#    'mmsi': 219058000,
#    'imo': 9806859,
#    'callsign': 'OXNP',
#    'flag': 'Denmark',
#    'dimA': 37,
#    'dimB': 26,
#    'dimC': 6,
#    'dimD': 7,
#    'length': 63.0,
#    'width': 13.0,
#    'typeOfShipAndCargo': 30,
#    'aisShiptype': 'fishing_boats',
#    'updateTime': '2021-08-13T12:12:01Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T13:30:07Z',
#    'eta': '2021-03-30T22:46:00Z',
#    'dest': 'FISHING CPA 0.5NM',
#    'draught': 7.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:03Z',
#    'src': 'T-AIS',
#    'lon': 4.864115,
#    'lat': 54.771926666666666,
#    'sog': 3.4,
#    'cog': 159.8,
#    'hdg': 163.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-21T13:49:34Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'CMA CGM VOLGA',
#    'mmsi': 256169000,
#    'imo': 9705081,
#    'callsign': '9HA3846',
#    'flag': 'Malta',
#    'dimA': 122,
#    'dimB': 178,
#    'dimC': 30,
#    'dimD': 19,
#    'length': 300.0,
#    'width': 49.0,
#    'typeOfShipAndCargo': 71,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2017-11-29T22:45:19Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:30:53Z',
#    'eta': '2021-08-27T11:00:00Z',
#    'dest': 'MYPKG',
#    'draught': 13.3,
#    'source': 'T-AIS',
#    'cargotype': 1},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:05Z',
#    'src': 'T-AIS',
#    'lon': 95.42408333333333,
#    'lat': 6.196583333333334,
#    'sog': 10.9,
#    'cog': 112.4,
#    'hdg': 113.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Port Klang',
#    'locode': 'MYPKG',
#    'calculatedEta': '2021-08-25T09:41:53Z',
#    'portCountry': 'Malaysia'},
#   'geoDetails': {'timeOfATChange': '2021-08-15T09:55:54Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'MARINA 2222',
#    'mmsi': 525500466,
#    'imo': 9902885,
#    'callsign': 'YDB3154',
#    'flag': 'Indonesia',
#    'dimA': 4,
#    'dimB': 25,
#    'dimC': 2,
#    'dimD': 6,
#    'length': 29.0,
#    'width': 8.0,
#    'typeOfShipAndCargo': 31,
#    'aisShiptype': 'towing_vessels',
#    'updateTime': '2021-01-24T22:00:47Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-01T12:34:33Z',
#    'eta': '2021-06-21T16:00:00Z',
#    'dest': 'MANDIODO',
#    'draught': None,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:01Z',
#    'src': 'S-AIS',
#    'lon': 122.65676,
#    'lat': -4.082973333333333,
#    'sog': 0.0,
#    'cog': 360.0,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 11},
#   'geoDetails': {'timeOfATChange': '2021-08-23T00:56:11Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'ITHACA STOCKHOLM',
#    'mmsi': 355882000,
#    'imo': 9563392,
#    'callsign': '3FHI7',
#    'flag': 'Panama',
#    'dimA': 153,
#    'dimB': 27,
#    'dimC': 14,
#    'dimD': 14,
#    'length': 180.0,
#    'width': 28.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-08T17:20:43Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-21T23:46:10Z',
#    'eta': '2021-08-08T19:00:00Z',
#    'dest': 'US HOU',
#    'draught': 6.9,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:55:53Z',
#    'src': 'S-AIS',
#    'lon': -85.2713,
#    'lat': 21.39242,
#    'sog': 13.6,
#    'cog': 306.5,
#    'hdg': 304.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Houston',
#    'locode': 'USHOU',
#    'portCountry': 'United States of America'},
#   'geoDetails': {'timeOfATChange': '2021-08-21T20:48:51Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'ZENIT',
#    'mmsi': 247556000,
#    'imo': 8815920,
#    'callsign': 'IMMZ',
#    'flag': 'Italy',
#    'dimA': 15,
#    'dimB': 20,
#    'dimC': 5,
#    'dimD': 6,
#    'length': 35.0,
#    'width': 11.0,
#    'typeOfShipAndCargo': 60,
#    'aisShiptype': 'passenger_ships',
#    'updateTime': '2017-12-01T13:14:28Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:56:17Z',
#    'eta': '2021-08-11T20:00:00Z',
#    'dest': 'TERMOLI',
#    'draught': 2.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-12T11:44:12Z',
#    'src': 'T-AIS',
#    'lon': 15.004166666666666,
#    'lat': 42.00532333333334,
#    'sog': 0.0,
#    'cog': 360.0,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 5},
#   'voyageDetails': {'destination': 'Termoli',
#    'locode': 'ITTMI',
#    'portCountry': 'Italy'},
#   'geoDetails': {'currentPort': 'Termoli',
#    'currentPortLocode': 'ITTMI',
#    'currentBerth': 'Termoli Port',
#    'timeOfATChange': '2021-08-11T18:13:37Z',
#    'status': 'moored',
#    'portCountry': 'Italy'}},
#  {'aisStatic': {'name': 'TOPAZ SEEMA',
#    'mmsi': 657149300,
#    'imo': 9694127,
#    'callsign': '5ODL4',
#    'flag': 'Nigeria',
#    'dimA': 16,
#    'dimB': 59,
#    'dimC': 4,
#    'dimD': 12,
#    'length': 75.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 90,
#    'aisShiptype': 'others',
#    'updateTime': '2020-08-28T10:20:21Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T22:05:07Z',
#    'eta': '2021-08-15T03:00:00Z',
#    'dest': 'DOUALA ANCHORAGE',
#    'draught': 6.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:07Z',
#    'src': 'S-AIS',
#    'lon': 9.55422,
#    'lat': 3.89776,
#    'sog': 0.2,
#    'cog': 104.1,
#    'hdg': 195.0,
#    'rot': 0,
#    'navStatus': 1},
#   'voyageDetails': {'destination': 'Douala',
#    'locode': 'CMDLA',
#    'portCountry': 'Cameroon'},
#   'geoDetails': {'timeOfATChange': '2021-08-20T22:01:50Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'NAUTICA TG PUTERI 28',
#    'mmsi': 533130499,
#    'imo': 9762132,
#    'callsign': '9MVP8',
#    'flag': 'Malaysia',
#    'dimA': 8,
#    'dimB': 20,
#    'dimC': 7,
#    'dimD': 5,
#    'length': 28.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2020-04-18T03:01:29Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-21T10:26:38Z',
#    'eta': '2021-06-06T05:00:00Z',
#    'dest': 'K.KINABALU ANCHORAGE',
#    'draught': 4.4,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:22Z',
#    'src': 'S-AIS',
#    'lon': 115.89443333333334,
#    'lat': 7.093525,
#    'sog': 6.5,
#    'cog': 166.5,
#    'hdg': 164.0,
#    'rot': -12,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T11:39:04Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'DUX BENEFIT',
#    'mmsi': 353316000,
#    'imo': 9109378,
#    'callsign': 'H9SA',
#    'flag': 'Panama',
#    'dimA': 156,
#    'dimB': 32,
#    'dimC': 12,
#    'dimD': 19,
#    'length': 188.0,
#    'width': 31.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2020-01-07T03:31:11Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-17T18:08:28Z',
#    'eta': '2021-08-18T06:00:00Z',
#    'dest': 'CJK',
#    'draught': 11.1,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:33Z',
#    'src': 'T-AIS',
#    'lon': 122.6349,
#    'lat': 31.240216666666665,
#    'sog': 0.2,
#    'cog': 340.0,
#    'hdg': 46.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-18T18:11:09Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'SITC WEIHAI',
#    'mmsi': 477537100,
#    'imo': 9322231,
#    'callsign': 'VRPU2',
#    'flag': 'Hong Kong',
#    'dimA': 120,
#    'dimB': 23,
#    'dimC': 12,
#    'dimD': 11,
#    'length': 143.0,
#    'width': 23.0,
#    'typeOfShipAndCargo': 71,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-30T02:27:46Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:27:02Z',
#    'eta': '2021-08-24T21:30:00Z',
#    'dest': 'CN SHA',
#    'draught': 6.7,
#    'source': 'T-AIS',
#    'cargotype': 1},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:33Z',
#    'src': 'T-AIS',
#    'lon': 122.71949666666667,
#    'lat': 31.027436666666667,
#    'sog': 0.2,
#    'cog': 1.4,
#    'hdg': 71.0,
#    'rot': 0,
#    'navStatus': 1},
#   'voyageDetails': {'destination': 'Shanghai',
#    'locode': 'CNSHA',
#    'calculatedEta': '2021-08-24T16:16:19Z',
#    'portCountry': 'China'},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-24T12:56:33Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'DESTRIERO SECONDO',
#    'mmsi': 247097800,
#    'imo': 8982785,
#    'callsign': 'INLI',
#    'flag': 'Italy',
#    'dimA': 10,
#    'dimB': 16,
#    'dimC': 2,
#    'dimD': 3,
#    'length': 26.0,
#    'width': 5.0,
#    'typeOfShipAndCargo': 0,
#    'aisShiptype': 'others',
#    'updateTime': '2017-12-06T07:11:27Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T15:46:39Z',
#    'eta': '2021-12-31T17:00:00Z',
#    'dest': 'VASTO\\I',
#    'draught': 1.6,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:35Z',
#    'src': 'T-AIS',
#    'lon': 14.946711666666667,
#    'lat': 42.212988333333335,
#    'sog': 1.3,
#    'cog': 39.8,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Vasto',
#    'locode': 'ITVSO',
#    'portCountry': 'Italy'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:56:35Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'HEMUS',
#    'mmsi': 256998000,
#    'imo': 9354791,
#    'callsign': '9HHP9',
#    'flag': 'Malta',
#    'dimA': 158,
#    'dimB': 28,
#    'dimC': 15,
#    'dimD': 15,
#    'length': 186.0,
#    'width': 30.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-07-12T11:06:50Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:19:58Z',
#    'eta': '2021-09-04T15:00:00Z',
#    'dest': 'GHENT',
#    'draught': 9.5,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:36Z',
#    'src': 'T-AIS',
#    'lon': 27.313951666666668,
#    'lat': 40.64828,
#    'sog': 12.3,
#    'cog': 243.4,
#    'hdg': 243.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Ghent',
#    'locode': 'BEGNE',
#    'portCountry': 'Belgium'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T03:04:53Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'MARI INNOVATOR ST',
#    'mmsi': 257811000,
#    'imo': 9909572,
#    'callsign': 'LALK8',
#    'flag': 'Norway',
#    'dimA': 0,
#    'dimB': 0,
#    'dimC': 0,
#    'dimD': 0,
#    'length': 0.0,
#    'width': 0.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2021-08-20T02:45:48Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T05:09:51Z',
#    'eta': '2021-08-27T10:00:00Z',
#    'dest': 'MARI INNOVATOR S/T',
#    'draught': None,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:41Z',
#    'src': 'T-AIS',
#    'lon': 129.61931833333333,
#    'lat': 36.95595333333333,
#    'sog': 6.6,
#    'cog': 290.9,
#    'hdg': 260.0,
#    'rot': -22,
#    'navStatus': 3},
#   'geoDetails': {'timeOfATChange': '2021-08-23T04:25:45Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'AREL 5',
#    'mmsi': 271044718,
#    'imo': 8511940,
#    'callsign': 'TCA4461',
#    'flag': 'Turkey',
#    'dimA': 78,
#    'dimB': 10,
#    'dimC': 3,
#    'dimD': 9,
#    'length': 88.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2019-05-07T18:36:05Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:09:23Z',
#    'eta': '2021-08-26T03:00:00Z',
#    'dest': 'DILISKELESI',
#    'draught': 5.2,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:42Z',
#    'src': 'T-AIS',
#    'lon': 26.672341666666668,
#    'lat': 39.114898333333336,
#    'sog': 7.6,
#    'cog': 353.3,
#    'hdg': 352.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Gebze',
#    'locode': 'TRGEB',
#    'portCountry': 'Turkey'},
#   'geoDetails': {'timeOfATChange': '2021-08-22T15:32:52Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'KMP TAKABONERATE',
#    'mmsi': 525201122,
#    'imo': 9925318,
#    'callsign': 'YDFT2',
#    'flag': 'Indonesia',
#    'dimA': 47,
#    'dimB': 12,
#    'dimC': 10,
#    'dimD': 10,
#    'length': 59.0,
#    'width': 20.0,
#    'typeOfShipAndCargo': 0,
#    'aisShiptype': 'others',
#    'updateTime': '2020-12-19T12:23:44Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2020-12-31T13:14:21Z',
#    'eta': None,
#    'dest': '',
#    'draught': None,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:23Z',
#    'src': 'S-AIS',
#    'lon': 120.51798833333334,
#    'lat': -5.834816666666667,
#    'sog': 0.0,
#    'cog': 286.9,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T22:41:50Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'METHANE JULIA LOUISE',
#    'mmsi': 310584000,
#    'imo': 9412880,
#    'callsign': 'ZCEB2',
#    'flag': 'Bermuda',
#    'dimA': 232,
#    'dimB': 58,
#    'dimC': 20,
#    'dimD': 25,
#    'length': 290.0,
#    'width': 45.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-05-26T15:14:03Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T23:12:52Z',
#    'eta': '2021-08-31T22:00:00Z',
#    'dest': 'FOR ORDERS',
#    'draught': 12.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:29Z',
#    'src': 'S-AIS',
#    'lon': 127.95952,
#    'lat': 4.198393333333334,
#    'sog': 13.9,
#    'cog': 20.7,
#    'hdg': 20.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-20T09:43:39Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'TRADEWIND PASSION',
#    'mmsi': 355973000,
#    'imo': 9483619,
#    'callsign': '3EPL5',
#    'flag': 'Panama',
#    'dimA': 100,
#    'dimB': 19,
#    'dimC': 7,
#    'dimD': 5,
#    'length': 119.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2017-12-02T08:50:48Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:10:07Z',
#    'eta': '2021-08-23T14:50:00Z',
#    'dest': 'GYNAM',
#    'draught': 4.5,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:24Z',
#    'src': 'S-AIS',
#    'lon': -57.52554166666667,
#    'lat': 6.199335,
#    'sog': 0.0,
#    'cog': 301.9,
#    'hdg': 181.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'New Amsterdam',
#    'locode': 'GYNAM',
#    'portCountry': 'Guyana'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T22:52:02Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'SD ACHIEVER',
#    'mmsi': 636019250,
#    'imo': 9740639,
#    'callsign': 'D5TQ3',
#    'flag': 'Liberia',
#    'dimA': 15,
#    'dimB': 55,
#    'dimC': 48,
#    'dimD': 14,
#    'length': 70.0,
#    'width': 62.0,
#    'typeOfShipAndCargo': 90,
#    'aisShiptype': 'others',
#    'updateTime': '2021-08-21T01:52:16Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:56:51Z',
#    'eta': None,
#    'dest': '',
#    'draught': None,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T04:03:46Z',
#    'src': 'T-AIS',
#    'lon': 49.715555,
#    'lat': 28.374966666666666,
#    'sog': 0.0,
#    'cog': 201.9,
#    'hdg': 331.0,
#    'rot': 0,
#    'navStatus': 15},
#   'geoDetails': {'timeOfATChange': '2021-08-21T01:11:26Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'TRAWIND GLORY',
#    'mmsi': 671801000,
#    'imo': 8718483,
#    'callsign': '5VEL3',
#    'flag': 'Togo',
#    'dimA': 57,
#    'dimB': 13,
#    'dimC': 2,
#    'dimD': 10,
#    'length': 70.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2019-10-30T04:13:30Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T00:25:04Z',
#    'eta': '2021-08-25T03:00:00Z',
#    'dest': 'JP.AFG',
#    'draught': 4.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:22Z',
#    'src': 'S-AIS',
#    'lon': 138.73155,
#    'lat': 40.196466666666666,
#    'sog': 6.6,
#    'cog': 120.4,
#    'hdg': 130.0,
#    'rot': -128,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Akitafunagawa',
#    'locode': 'JPAFG',
#    'portCountry': 'Japan'},
#   'geoDetails': {'timeOfATChange': '2021-08-22T13:54:10Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'ETOILE',
#    'mmsi': 229263000,
#    'imo': 9301469,
#    'callsign': '9HA3184',
#    'flag': 'Malta',
#    'dimA': 16,
#    'dimB': 194,
#    'dimC': 22,
#    'dimD': 8,
#    'length': 210.0,
#    'width': 30.0,
#    'typeOfShipAndCargo': 73,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-08-13T09:30:30Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T07:59:13Z',
#    'eta': '2021-08-26T02:00:00Z',
#    'dest': 'KR PUS',
#    'draught': 9.3,
#    'source': 'T-AIS',
#    'cargotype': 3},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:41Z',
#    'src': 'S-AIS',
#    'lon': 138.90771166666667,
#    'lat': 40.61862333333333,
#    'sog': 16.5,
#    'cog': 244.0,
#    'hdg': 244.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Busan',
#    'locode': 'KRPUS',
#    'calculatedEta': '2021-08-25T18:01:13Z',
#    'portCountry': 'South Korea'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T00:51:41Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'GREYMAN EXPRESS',
#    'mmsi': 565876000,
#    'imo': 9733777,
#    'callsign': '9V3518',
#    'flag': 'Singapore',
#    'dimA': 20,
#    'dimB': 115,
#    'dimC': 14,
#    'dimD': 6,
#    'length': 135.0,
#    'width': 20.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2017-12-04T17:30:57Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-21T12:14:32Z',
#    'eta': '2021-08-28T01:00:00Z',
#    'dest': 'HON LA-VN',
#    'draught': 6.3,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:33Z',
#    'src': 'S-AIS',
#    'lon': 123.081695,
#    'lat': 5.560453333333333,
#    'sog': 15.0,
#    'cog': 333.1,
#    'hdg': 328.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-21T09:09:43Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'FLOURISH POWER',
#    'mmsi': 477817300,
#    'imo': 9631266,
#    'callsign': 'VRJS8',
#    'flag': 'Hong Kong',
#    'dimA': 200,
#    'dimB': 35,
#    'dimC': 22,
#    'dimD': 16,
#    'length': 235.0,
#    'width': 38.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2019-09-21T03:59:19Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T17:17:02Z',
#    'eta': '2021-08-30T17:00:00Z',
#    'dest': 'CN QDG',
#    'draught': 11.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:41Z',
#    'src': 'S-AIS',
#    'lon': 120.43331333333333,
#    'lat': 8.640491666666666,
#    'sog': 12.8,
#    'cog': 357.7,
#    'hdg': 358.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-16T16:25:28Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'SPAN ASIA 3',
#    'mmsi': 548819200,
#    'imo': 7824613,
#    'callsign': 'DUH3214',
#    'flag': 'Philippines',
#    'dimA': 94,
#    'dimB': 16,
#    'dimC': 11,
#    'dimD': 5,
#    'length': 110.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-10-29T05:06:39Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:04:44Z',
#    'eta': '2021-08-23T20:30:00Z',
#    'dest': 'ANCH TALISAY',
#    'draught': 6.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:41Z',
#    'src': 'S-AIS',
#    'lon': 123.17760833333334,
#    'lat': 9.021281666666667,
#    'sog': 11.2,
#    'cog': 225.2,
#    'hdg': 190.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-24T05:25:39Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'OLYMPIC TRUST',
#    'mmsi': 538005797,
#    'imo': 9437177,
#    'callsign': 'V7HA2',
#    'flag': 'Marshall Islands',
#    'dimA': 283,
#    'dimB': 56,
#    'dimC': 23,
#    'dimD': 37,
#    'length': 339.0,
#    'width': 60.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2018-11-07T04:23:49Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-21T11:42:01Z',
#    'eta': '2021-09-05T13:00:00Z',
#    'dest': 'RIZHAO',
#    'draught': 19.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:47Z',
#    'src': 'S-AIS',
#    'lon': 91.07231666666667,
#    'lat': 6.166308333333333,
#    'sog': 11.7,
#    'cog': 85.9,
#    'hdg': 79.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Rizhao',
#    'locode': 'CNRZH',
#    'portCountry': 'China'},
#   'geoDetails': {'timeOfATChange': '2021-08-14T18:33:15Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'DONNA J BOUCHARD',
#    'mmsi': 367707490,
#    'imo': 9753181,
#    'callsign': 'WDI5332',
#    'flag': 'United States of America',
#    'dimA': 214,
#    'dimB': 25,
#    'dimC': 14,
#    'dimD': 14,
#    'length': 239.0,
#    'width': 28.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2020-05-29T21:04:31Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:47:40Z',
#    'eta': '2021-04-16T19:46:00Z',
#    'dest': 'BELLE CHASE',
#    'draught': 7.2,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:02Z',
#    'src': 'T-AIS',
#    'lon': -89.94546833333334,
#    'lat': 29.87712,
#    'sog': 0.0,
#    'cog': 269.8,
#    'hdg': 116.0,
#    'rot': 7,
#    'navStatus': 1},
#   'geoDetails': {'timeOfATChange': '2021-08-19T20:23:35Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'SUNRISE SAMBU',
#    'mmsi': 440213000,
#    'imo': 9288007,
#    'callsign': 'DSNR6',
#    'flag': 'South Korea',
#    'dimA': 76,
#    'dimB': 16,
#    'dimC': 6,
#    'dimD': 8,
#    'length': 92.0,
#    'width': 14.0,
#    'typeOfShipAndCargo': 82,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-03-19T02:12:27Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:57:03Z',
#    'eta': '2021-08-25T21:00:00Z',
#    'dest': 'KR USN WM',
#    'draught': 6.2,
#    'source': 'T-AIS',
#    'cargotype': 2},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:00Z',
#    'src': 'T-AIS',
#    'lon': 129.36517,
#    'lat': 35.44296,
#    'sog': 0.1,
#    'cog': 141.1,
#    'hdg': 25.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Ulsan',
#    'locode': 'KRUSN',
#    'portCountry': 'South Korea'},
#   'geoDetails': {'currentPort': 'Ulsan',
#    'currentPortLocode': 'KRUSN',
#    'currentBerth': 'Ulsan Port',
#    'timeOfATChange': '2021-08-24T12:57:00Z',
#    'status': 'moored',
#    'portCountry': 'South Korea'}},
#  {'aisStatic': {'name': 'GENIUS STAR XI',
#    'mmsi': 373928000,
#    'imo': 9622710,
#    'callsign': '3FGS3',
#    'flag': 'Panama',
#    'dimA': 106,
#    'dimB': 18,
#    'dimC': 16,
#    'dimD': 6,
#    'length': 124.0,
#    'width': 22.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2017-12-02T03:31:51Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T09:13:08Z',
#    'eta': '2021-08-18T01:00:00Z',
#    'dest': 'CN SGH',
#    'draught': 5.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:03Z',
#    'src': 'T-AIS',
#    'lon': 122.57819166666667,
#    'lat': 31.013681666666667,
#    'sog': 0.2,
#    'cog': 6.6,
#    'hdg': 82.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-18T01:38:39Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'HARALD',
#    'mmsi': 230990270,
#    'imo': 5412026,
#    'callsign': 'OIWX',
#    'flag': 'Finland',
#    'dimA': 9,
#    'dimB': 20,
#    'dimC': 3,
#    'dimD': 5,
#    'length': 29.0,
#    'width': 8.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2018-11-07T04:22:20Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T21:48:28Z',
#    'eta': '2022-01-24T17:00:00Z',
#    'dest': 'KANTVIK',
#    'draught': 4.2,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:06Z',
#    'src': 'T-AIS',
#    'lon': 24.37475,
#    'lat': 60.08168833333333,
#    'sog': 0.0,
#    'cog': 295.3,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 5},
#   'voyageDetails': {'destination': 'Kantvik',
#    'locode': 'FIKNT',
#    'portCountry': 'Finland'},
#   'geoDetails': {'currentPort': 'Kantvik',
#    'currentPortLocode': 'FIKNT',
#    'currentBerth': 'Kantvik Port',
#    'timeOfATChange': '2021-07-29T16:27:22Z',
#    'status': 'moored',
#    'portCountry': 'Finland'}},
#  {'aisStatic': {'name': 'HARVEST DAWN N82',
#    'mmsi': 232012896,
#    'imo': 8684462,
#    'callsign': 'MCIE3',
#    'flag': 'United Kingdom',
#    'dimA': 15,
#    'dimB': 7,
#    'dimC': 3,
#    'dimD': 3,
#    'length': 22.0,
#    'width': 6.0,
#    'typeOfShipAndCargo': 30,
#    'aisShiptype': 'fishing_boats',
#    'updateTime': '2019-03-15T12:32:59Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-17T01:28:53Z',
#    'eta': '2021-04-19T10:00:00Z',
#    'dest': 'FISHING GROUNDS',
#    'draught': 3.5,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:43Z',
#    'src': 'S-AIS',
#    'lon': -6.93504,
#    'lat': 56.779853333333335,
#    'sog': 2.6,
#    'cog': 64.3,
#    'hdg': 62.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:56:43Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'M.T.V.L.17',
#    'mmsi': 567001990,
#    'imo': 9805855,
#    'callsign': 'HSB5681',
#    'flag': 'Thailand',
#    'dimA': 55,
#    'dimB': 20,
#    'dimC': 6,
#    'dimD': 6,
#    'length': 75.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2018-11-07T03:09:12Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:52:50Z',
#    'eta': '2021-08-25T06:00:00Z',
#    'dest': 'SONGKHLA',
#    'draught': 4.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:16Z',
#    'src': 'T-AIS',
#    'lon': 100.42328666666667,
#    'lat': 8.385775,
#    'sog': 8.6,
#    'cog': 166.3,
#    'hdg': 166.0,
#    'rot': 5,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Songkhla',
#    'locode': 'THSGZ',
#    'portCountry': 'Thailand'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T10:37:36Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'NAN LIAN 7',
#    'mmsi': 413363710,
#    'imo': 9644249,
#    'callsign': 'BHSV4',
#    'flag': 'China',
#    'dimA': 93,
#    'dimB': 20,
#    'dimC': 7,
#    'dimD': 10,
#    'length': 113.0,
#    'width': 17.0,
#    'typeOfShipAndCargo': 82,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-12-10T05:22:24Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T12:13:04Z',
#    'eta': '2021-08-25T04:00:00Z',
#    'dest': 'NING BO',
#    'draught': 4.5,
#    'source': 'T-AIS',
#    'cargotype': 2},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:21Z',
#    'src': 'T-AIS',
#    'lon': 121.826385,
#    'lat': 30.358578333333334,
#    'sog': 11.8,
#    'cog': 221.4,
#    'hdg': 214.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Ningbo',
#    'locode': 'CNNGB',
#    'portCountry': 'China'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T21:16:08Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'LADY MARITE',
#    'mmsi': 353544000,
#    'imo': 9544712,
#    'callsign': '3FLA',
#    'flag': 'Panama',
#    'dimA': 194,
#    'dimB': 31,
#    'dimC': 12,
#    'dimD': 20,
#    'length': 225.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2019-12-02T07:19:18Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-20T11:55:10Z',
#    'eta': '2021-08-19T22:00:00Z',
#    'dest': 'BALIKPAPAN,INDONDSI',
#    'draught': 7.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:56:53Z',
#    'src': 'S-AIS',
#    'lon': 120.53628333333333,
#    'lat': 10.149616666666667,
#    'sog': 13.2,
#    'cog': 1.0,
#    'hdg': 359.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Balikpapan',
#    'locode': 'IDBPN',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'timeOfATChange': '2021-08-20T02:15:35Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'NANJING EXPRESS',
#    'mmsi': 477188900,
#    'imo': 9497098,
#    'callsign': 'VRMI9',
#    'flag': 'Hong Kong',
#    'dimA': 190,
#    'dimB': 25,
#    'dimC': 15,
#    'dimD': 22,
#    'length': 215.0,
#    'width': 37.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-07T13:10:24Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-10T18:27:51Z',
#    'eta': '2021-08-14T08:00:00Z',
#    'dest': 'ID BPN',
#    'draught': 8.2,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:00Z',
#    'src': 'S-AIS',
#    'lon': 120.46234666666666,
#    'lat': 10.65947,
#    'sog': 12.7,
#    'cog': 6.8,
#    'hdg': 6.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Balikpapan',
#    'locode': 'IDBPN',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'timeOfATChange': '2021-08-21T14:21:08Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'ANANGEL VOYAGER',
#    'mmsi': 241032000,
#    'imo': 9458688,
#    'callsign': 'SVBA9',
#    'flag': 'Greece',
#    'dimA': 248,
#    'dimB': 44,
#    'dimC': 25,
#    'dimD': 20,
#    'length': 292.0,
#    'width': 45.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2019-11-23T05:30:23Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T04:49:25Z',
#    'eta': '2021-09-01T05:00:00Z',
#    'dest': 'PORT HEDLAND',
#    'draught': 8.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:09Z',
#    'src': 'S-AIS',
#    'lon': 120.3842,
#    'lat': 8.542183333333334,
#    'sog': 11.2,
#    'cog': 179.0,
#    'hdg': 178.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Port Hedland',
#    'locode': 'AUPHE',
#    'portCountry': 'Australia'},
#   'geoDetails': {'timeOfATChange': '2021-08-18T07:16:35Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'FRONT PRINCESS',
#    'mmsi': 538007562,
#    'imo': 9788904,
#    'callsign': 'V7US5',
#    'flag': 'Marshall Islands',
#    'dimA': 287,
#    'dimB': 49,
#    'dimC': 30,
#    'dimD': 30,
#    'length': 336.0,
#    'width': 60.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2018-11-10T00:14:07Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T13:09:17Z',
#    'eta': '2021-08-31T19:00:00Z',
#    'dest': 'FOR ORDERS',
#    'draught': 11.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:00Z',
#    'src': 'S-AIS',
#    'lon': 74.00250666666666,
#    'lat': 11.705185,
#    'sog': 10.1,
#    'cog': 327.3,
#    'hdg': 328.0,
#    'rot': 1,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T11:14:15Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'FV NICOLAS JEREMY',
#    'mmsi': 226183000,
#    'imo': 9228667,
#    'callsign': 'FTMU',
#    'flag': 'France',
#    'dimA': 12,
#    'dimB': 12,
#    'dimC': 6,
#    'dimD': 2,
#    'length': 24.0,
#    'width': 8.0,
#    'typeOfShipAndCargo': 30,
#    'aisShiptype': 'fishing_boats',
#    'updateTime': '2020-09-14T07:28:53Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-19T15:33:29Z',
#    'eta': None,
#    'dest': '',
#    'draught': 3.8,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:23Z',
#    'src': 'T-AIS',
#    'lon': 0.9618333333333333,
#    'lat': 50.4103,
#    'sog': 2.5,
#    'cog': 163.8,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 15},
#   'geoDetails': {'timeOfATChange': '2021-08-23T00:27:54Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'SEAFRIEND',
#    'mmsi': 229407000,
#    'imo': 9629574,
#    'callsign': '9HA3308',
#    'flag': 'Malta',
#    'dimA': 149,
#    'dimB': 34,
#    'dimC': 10,
#    'dimD': 22,
#    'length': 183.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2019-01-16T13:09:19Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T20:35:23Z',
#    'eta': '2021-08-20T21:00:00Z',
#    'dest': 'PA BLB',
#    'draught': 7.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:06Z',
#    'src': 'S-AIS',
#    'lon': -82.11349166666666,
#    'lat': 17.482731666666666,
#    'sog': 13.5,
#    'cog': 321.2,
#    'hdg': 326.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Balboa',
#    'locode': 'PABLB',
#    'portCountry': 'Panama'},
#   'geoDetails': {'timeOfATChange': '2021-08-22T17:13:16Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'AMBERJACK LNG',
#    'mmsi': 215534000,
#    'imo': 9845776,
#    'callsign': '9HA5163',
#    'flag': 'Malta',
#    'dimA': 235,
#    'dimB': 64,
#    'dimC': 13,
#    'dimD': 33,
#    'length': 299.0,
#    'width': 46.0,
#    'typeOfShipAndCargo': 84,
#    'aisShiptype': 'tankships',
#    'updateTime': '2020-06-25T06:36:25Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T10:45:44Z',
#    'eta': '2021-08-28T22:00:00Z',
#    'dest': 'FOR ORDERS',
#    'draught': 9.4,
#    'source': 'S-AIS',
#    'cargotype': 4},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:03Z',
#    'src': 'S-AIS',
#    'lon': -76.21803,
#    'lat': 25.802605,
#    'sog': 11.5,
#    'cog': 262.3,
#    'hdg': 260.0,
#    'rot': 1,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-10T15:19:51Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'A KOU',
#    'mmsi': 353598000,
#    'imo': 9343699,
#    'callsign': '3EDD7',
#    'flag': 'Panama',
#    'dimA': 112,
#    'dimB': 30,
#    'dimC': 12,
#    'dimD': 10,
#    'length': 142.0,
#    'width': 22.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-05-11T12:17:15Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T07:55:11Z',
#    'eta': '2021-08-26T19:00:00Z',
#    'dest': 'JP OSA',
#    'draught': 6.6,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:25Z',
#    'src': 'T-AIS',
#    'lon': 122.98985,
#    'lat': 31.080766666666666,
#    'sog': 15.5,
#    'cog': 67.0,
#    'hdg': 65.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Osaka',
#    'locode': 'JPOSA',
#    'calculatedEta': '2021-08-26T01:38:18Z',
#    'portCountry': 'Japan'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T07:00:23Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'SPRING ARAM',
#    'mmsi': 477147500,
#    'imo': 9325386,
#    'callsign': 'VRRG7',
#    'flag': 'Hong Kong',
#    'dimA': 108,
#    'dimB': 17,
#    'dimC': 15,
#    'dimD': 5,
#    'length': 125.0,
#    'width': 20.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2017-12-04T09:56:31Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T11:30:54Z',
#    'eta': '2021-08-21T08:00:00Z',
#    'dest': 'CH SHA',
#    'draught': 7.3,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:57:26Z',
#    'src': 'T-AIS',
#    'lon': 122.738575,
#    'lat': 31.05824,
#    'sog': 0.4,
#    'cog': 59.8,
#    'hdg': 62.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'currentAnchorage': 'Shanghai Anchorage',
#    'timeOfATChange': '2021-08-21T02:55:08Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'BEAN STAR',
#    'mmsi': 477797100,
#    'imo': 9310771,
#    'callsign': 'VRCT3',
#    'flag': 'Hong Kong',
#    'dimA': 150,
#    'dimB': 27,
#    'dimC': 8,
#    'dimD': 20,
#    'length': 177.0,
#    'width': 28.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-07-06T23:06:09Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T03:40:16Z',
# ...
#    'timeOfATChange': '2021-08-24T12:51:35Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'KM JAKARTA',
#    'mmsi': 636018221,
#    'imo': 9820958,
#    'callsign': 'D5OR9',
#    'flag': 'Liberia',
#    'dimA': 173,
#    'dimB': 26,
#    'dimC': 8,
#    'dimD': 24,
#    'length': 199.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-07-23T20:40:02Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T11:34:52Z',
#    'eta': '2021-08-22T03:00:00Z',
#    'dest': 'KENDARI',
#    'draught': 13.4,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:51:36Z',
#    'src': 'S-AIS',
#    'lon': 122.34319833333333,
#    'lat': -3.2954483333333333,
#    'sog': 0.1,
#    'cog': 96.4,
#    'hdg': 321.0,
#    'rot': 0,
#    'navStatus': 1},
#   'voyageDetails': {'destination': 'Kendari',
#    'locode': 'IDKDI',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'timeOfATChange': '2021-08-22T02:12:40Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'TEGAS MAKMUR',
#    'mmsi': 533000713,
#    'imo': 9438755,
#    'callsign': '9WHN8',
#    'flag': 'Malaysia',
#    'dimA': 10,
#    'dimB': 32,
#    'dimC': 3,
#    'dimD': 4,
#    'length': 42.0,
#    'width': 7.0,
#    'typeOfShipAndCargo': 60,
#    'aisShiptype': 'passenger_ships',
#    'updateTime': '2018-05-11T22:42:30Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-12T23:49:16Z',
#    'eta': '2021-08-10T23:30:00Z',
#    'dest': 'MIRI',
#    'draught': 1.4,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:51:52Z',
#    'src': 'S-AIS',
#    'lon': 112.477785,
#    'lat': 4.69375,
#    'sog': 0.2,
#    'cog': 316.0,
#    'hdg': 234.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Miri',
#    'locode': 'MYMYY',
#    'portCountry': 'Malaysia'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T20:31:14Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'TB.TJA 289',
#    'mmsi': 525010093,
#    'imo': 9351660,
#    'callsign': 'YDA6304',
#    'flag': 'Indonesia',
#    'dimA': 6,
#    'dimB': 23,
#    'dimC': 6,
#    'dimD': 3,
#    'length': 29.0,
#    'width': 9.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2020-02-21T17:00:18Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T03:36:32Z',
#    'eta': '2021-07-28T15:00:00Z',
#    'dest': 'KOTBARU',
#    'draught': 3.5,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:51:52Z',
#    'src': 'S-AIS',
#    'lon': 115.504045,
#    'lat': -3.8345516666666666,
#    'sog': 0.4,
#    'cog': 97.7,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 8},
#   'geoDetails': {'timeOfATChange': '2021-08-24T05:38:11Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'SMEW',
#    'mmsi': 210953000,
#    'imo': 9688843,
#    'callsign': '5BZW3',
#    'flag': 'Cyprus',
#    'dimA': 150,
#    'dimB': 30,
#    'dimC': 10,
#    'dimD': 20,
#    'length': 180.0,
#    'width': 30.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-01T18:47:31Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T23:05:42Z',
#    'eta': '2021-08-23T13:00:00Z',
#    'dest': 'BAHODOPI',
#    'draught': 9.9,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:51:57Z',
#    'src': 'S-AIS',
#    'lon': 122.17622166666666,
#    'lat': -2.78834,
#    'sog': 0.2,
#    'cog': 326.8,
#    'hdg': 80.0,
#    'rot': 0,
#    'navStatus': 1},
#   'geoDetails': {'timeOfATChange': '2021-08-24T05:18:57Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'BSTEEL HARMONY',
#    'mmsi': 636015921,
#    'imo': 9621338,
#    'callsign': 'D5DN2',
#    'flag': 'Liberia',
#    'dimA': 281,
#    'dimB': 49,
#    'dimC': 22,
#    'dimD': 35,
#    'length': 330.0,
#    'width': 57.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-12T01:43:07Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T06:41:47Z',
#    'eta': '2021-08-30T04:00:00Z',
#    'dest': 'CN MJS',
#    'draught': 17.3,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:10Z',
#    'src': 'S-AIS',
#    'lon': 119.58233,
#    'lat': 3.261503333333333,
#    'sog': 12.3,
#    'cog': 0.8,
#    'hdg': 6.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Maji Shan',
#    'locode': 'CNMJS',
#    'portCountry': 'China'},
#   'geoDetails': {'timeOfATChange': '2021-08-19T12:12:03Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'DHARMA RUCITRA',
#    'mmsi': 525005324,
#    'imo': 6502945,
#    'callsign': 'YFEZ',
#    'flag': 'Indonesia',
#    'dimA': 30,
#    'dimB': 20,
#    'dimC': 6,
#    'dimD': 6,
#    'length': 50.0,
#    'width': 12.0,
#    'typeOfShipAndCargo': 0,
#    'aisShiptype': 'others',
#    'updateTime': '2019-10-07T07:14:13Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T05:14:47Z',
#    'eta': '2021-08-20T11:15:00Z',
#    'dest': 'KETAPANG',
#    'draught': 2.3,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:19Z',
#    'src': 'S-AIS',
#    'lon': 114.43622833333333,
#    'lat': -8.161515,
#    'sog': 0.1,
#    'cog': 254.5,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 3},
#   'voyageDetails': {'destination': 'Ketapang',
#    'locode': 'IDKTG',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'currentPort': 'Gilimanuk',
#    'currentPortLocode': 'IDGIL',
#    'currentBerth': 'Gilimanuk Port',
#    'timeOfATChange': '2021-08-24T12:52:19Z',
#    'status': 'moored',
#    'portCountry': 'Indonesia'}},
#  {'aisStatic': {'name': 'CYMONA GLORY',
#    'mmsi': 538004344,
#    'imo': 9510694,
#    'callsign': 'V7WN3',
#    'flag': 'Marshall Islands',
#    'dimA': 200,
#    'dimB': 35,
#    'dimC': 22,
#    'dimD': 10,
#    'length': 235.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2021-08-10T02:43:31Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-10T12:25:27Z',
#    'eta': '2021-08-14T08:00:00Z',
#    'dest': 'IN SRI',
#    'draught': 7.8,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:20Z',
#    'src': 'S-AIS',
#    'lon': 117.65568333333333,
#    'lat': -0.29086,
#    'sog': 0.0,
#    'cog': 183.0,
#    'hdg': 151.0,
#    'rot': 5,
#    'navStatus': 1},
#   'geoDetails': {'timeOfATChange': '2021-08-13T18:55:25Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'MT HELMY REJEKI',
#    'mmsi': 525024157,
#    'imo': 9052795,
#    'callsign': 'JZLJ',
#    'flag': 'Indonesia',
#    'dimA': 78,
#    'dimB': 15,
#    'dimC': 6,
#    'dimD': 10,
#    'length': 93.0,
#    'width': 16.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2021-08-01T20:22:45Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-17T15:25:17Z',
#    'eta': '2021-08-18T16:00:00Z',
#    'dest': 'MOROWALI ID',
#    'draught': 4.5,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:22Z',
#    'src': 'S-AIS',
#    'lon': 122.190805,
#    'lat': -4.7539316666666664,
#    'sog': 6.3,
#    'cog': 198.3,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T10:31:39Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'MBP TAMPAN',
#    'mmsi': 5250022,
#    'imo': 9258284,
#    'callsign': 'YDA6415',
#    'dimA': 4,
#    'dimB': 25,
#    'dimC': 4,
#    'dimD': 5,
#    'length': 29.0,
#    'width': 9.0,
#    'typeOfShipAndCargo': 31,
#    'aisShiptype': 'towing_vessels',
#    'updateTime': '2019-05-05T22:08:33Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-22T17:07:03Z',
#    'eta': '2021-09-26T10:00:00Z',
#    'dest': 'KLNS',
#    'draught': 3.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:28Z',
#    'src': 'S-AIS',
#    'lon': 114.46969,
#    'lat': -3.7281633333333333,
#    'sog': 2.2,
#    'cog': 236.8,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:52:28Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'EXPRESS 81',
#    'mmsi': 533132057,
#    'imo': 9724922,
#    'callsign': '9M2204',
#    'flag': 'Malaysia',
#    'dimA': 13,
#    'dimB': 27,
#    'dimC': 3,
#    'dimD': 5,
#    'length': 40.0,
#    'width': 8.0,
#    'typeOfShipAndCargo': 60,
#    'aisShiptype': 'passenger_ships',
#    'updateTime': '2021-05-08T00:24:44Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-24T09:15:03Z',
#    'eta': '2021-07-12T18:00:00Z',
#    'dest': 'MIRI MALAYSIA',
#    'draught': 1.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:30Z',
#    'src': 'S-AIS',
#    'lon': 113.13560666666666,
#    'lat': 3.923495,
#    'sog': 13.5,
#    'cog': 233.9,
#    'hdg': 232.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Miri',
#    'locode': 'MYMYY',
#    'portCountry': 'Malaysia'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T09:00:31Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'SINAR MATARAM',
#    'mmsi': 525009077,
#    'imo': 9545390,
#    'callsign': 'POTN',
#    'flag': 'Indonesia',
#    'dimA': 74,
#    'dimB': 14,
#    'dimC': 9,
#    'dimD': 5,
#    'length': 88.0,
#    'width': 14.0,
#    'typeOfShipAndCargo': 0,
#    'aisShiptype': 'others',
#    'updateTime': '2021-03-26T03:30:11Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-20T02:02:09Z',
#    'eta': '2021-08-21T08:00:00Z',
#    'dest': 'BONTANG',
#    'draught': 4.6,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:37Z',
#    'src': 'S-AIS',
#    'lon': 119.03866833333333,
#    'lat': 3.2910783333333335,
#    'sog': 9.3,
#    'cog': 359.7,
#    'hdg': 357.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T13:18:07Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'EXPRESS 79',
#    'mmsi': 372694000,
#    'imo': 9733090,
#    'callsign': 'HP4011',
#    'flag': 'Panama',
#    'dimA': 15,
#    'dimB': 25,
#    'dimC': 3,
#    'dimD': 5,
#    'length': 40.0,
#    'width': 8.0,
#    'typeOfShipAndCargo': 60,
#    'aisShiptype': 'passenger_ships',
#    'updateTime': '2021-02-02T17:46:04Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-07T23:12:53Z',
#    'eta': '2021-08-01T05:00:00Z',
#    'dest': 'FAIRLEY FIELD',
#    'draught': 1.7,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:38Z',
#    'src': 'S-AIS',
#    'lon': 114.20045666666667,
#    'lat': 4.56949,
#    'sog': 0.0,
#    'cog': 264.1,
#    'hdg': 153.0,
#    'rot': 0,
#    'navStatus': 0},
#   'geoDetails': {'currentPort': 'Kuala Belait',
#    'currentPortLocode': 'BNKUB',
#    'currentBerth': 'Kuala Belait Port',
#    'timeOfATChange': '2021-08-24T12:52:38Z',
#    'status': 'moored',
#    'portCountry': 'Brunei Darussalam'}},
#  {'aisStatic': {'name': 'ASPASIA LUCK',
#    'mmsi': 636015954,
#    'imo': 9223485,
#    'callsign': 'D5DR7',
#    'flag': 'Liberia',
#    'dimA': 195,
#    'dimB': 30,
#    'dimC': 14,
#    'dimD': 18,
#    'length': 225.0,
#    'width': 32.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2018-11-07T03:41:37Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-18T09:06:25Z',
#    'eta': '2021-08-21T06:00:00Z',
#    'dest': 'ID SRI',
#    'draught': 6.5,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:52:38Z',
#    'src': 'S-AIS',
#    'lon': 117.68023833333334,
#    'lat': -0.30873,
#    'sog': 0.1,
#    'cog': 270.4,
#    'hdg': 158.0,
#    'rot': 0,
#    'navStatus': 1},
#   'voyageDetails': {'destination': 'Samarinda',
#    'locode': 'IDSRI',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'timeOfATChange': '2021-08-24T12:52:38Z',
#    'status': 'anchorage'}},
#  {'aisStatic': {'name': 'TB.E MEGASTAR 53',
#    'mmsi': 525022112,
#    'imo': 9430478,
#    'callsign': 'YDA6336',
#    'flag': 'Indonesia',
#    'dimA': 0,
#    'dimB': 0,
#    'dimC': 0,
#    'dimD': 0,
#    'length': 0.0,
#    'width': 0.0,
#    'typeOfShipAndCargo': 32,
#    'aisShiptype': 'towing_vessels',
#    'updateTime': '2021-06-09T10:48:31Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T13:54:17Z',
#    'eta': '2021-08-23T09:21:00Z',
#    'dest': 'CELUKANBAWANGBALI',
#    'draught': 3.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:49:34Z',
#    'src': 'S-AIS',
#    'lon': 114.84511666666667,
#    'lat': -8.186788333333332,
#    'sog': 0.1,
#    'cog': 248.2,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'geoDetails': {'timeOfATChange': '2021-08-23T21:14:53Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'SL YAKAL',
#    'mmsi': 548059200,
#    'imo': 9298349,
#    'callsign': 'DUB2020',
#    'flag': 'Philippines',
#    'dimA': 67,
#    'dimB': 20,
#    'dimC': 11,
#    'dimD': 3,
#    'length': 87.0,
#    'width': 14.0,
#    'typeOfShipAndCargo': 80,
#    'aisShiptype': 'tankships',
#    'updateTime': '2021-01-23T07:00:02Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T05:52:31Z',
#    'eta': '2021-08-27T14:30:00Z',
#    'dest': 'LIMAY BATAAN',
#    'draught': 5.0,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:49:46Z',
#    'src': 'S-AIS',
#    'lon': 122.80885,
#    'lat': 6.612683333333333,
#    'sog': 8.3,
#    'cog': 293.0,
#    'hdg': 304.0,
#    'rot': 0,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Bataan',
#    'locode': 'PHBTN',
#    'portCountry': 'Philippines'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T03:37:16Z',
#    'status': 'moving'}},
#  {'aisStatic': {'name': 'KENDHAGA NUSANTARA 1',
#    'mmsi': 525101050,
#    'imo': 9829423,
#    'callsign': '',
#    'flag': 'Indonesia',
#    'dimA': 62,
#    'dimB': 12,
#    'dimC': 8,
#    'dimD': 9,
#    'length': 74.0,
#    'width': 17.0,
#    'typeOfShipAndCargo': 70,
#    'aisShiptype': 'cargo_ships',
#    'updateTime': '2017-12-21T04:46:26Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-23T23:28:45Z',
#    'eta': '2021-06-18T10:00:00Z',
#    'dest': 'LIRUNG _ INDO',
#    'draught': 3.0,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:49:51Z',
#    'src': 'S-AIS',
#    'lon': 126.67608,
#    'lat': 3.997341666666667,
#    'sog': 0.0,
#    'cog': 251.5,
#    'hdg': 139.0,
#    'rot': 0,
#    'navStatus': 8},
#   'geoDetails': {'timeOfATChange': '2021-08-20T04:35:46Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'TB.LEMBU BUANA II',
#    'mmsi': 525500465,
#    'imo': 8699091,
#    'callsign': 'YDB6419',
#    'flag': 'Indonesia',
#    'dimA': 0,
#    'dimB': 0,
#    'dimC': 0,
#    'dimD': 0,
#    'length': 0.0,
#    'width': 0.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2021-01-15T13:00:38Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-08-18T11:54:06Z',
#    'eta': '2021-08-15T14:00:00Z',
#    'dest': 'MUARA KEMBANG',
#    'draught': 3.5,
#    'source': 'T-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:49:51Z',
#    'src': 'S-AIS',
#    'lon': 116.9701,
#    'lat': -1.3189783333333334,
#    'sog': 0.1,
#    'cog': 207.3,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Muara',
#    'locode': 'BNMUA',
#    'portCountry': 'Brunei Darussalam'},
#   'geoDetails': {'timeOfATChange': '2021-08-23T04:47:28Z',
#    'status': 'waiting'}},
#  {'aisStatic': {'name': 'TB.MARINE VISTA II',
#    'mmsi': 525021373,
#    'imo': 7933177,
#    'callsign': 'YD3358',
#    'flag': 'Indonesia',
#    'dimA': 21,
#    'dimB': 18,
#    'dimC': 4,
#    'dimD': 2,
#    'length': 39.0,
#    'width': 6.0,
#    'typeOfShipAndCargo': 52,
#    'aisShiptype': 'tugboats',
#    'updateTime': '2018-11-13T12:47:45Z',
#    'aisClass': 'A'},
#   'aisVoyage': {'updateTime': '2021-06-06T00:27:34Z',
#    'eta': '2021-09-30T19:00:00Z',
#    'dest': 'PONTIANAK',
#    'draught': 2.8,
#    'source': 'S-AIS',
#    'cargotype': 0},
#   'aisPosition': {'timeReceived': '2021-08-24T12:49:52Z',
#    'src': 'S-AIS',
#    'lon': 122.25730166666666,
#    'lat': -3.0105916666666666,
#    'sog': 0.0,
#    'cog': 108.4,
#    'hdg': 511.0,
#    'rot': -128,
#    'navStatus': 0},
#   'voyageDetails': {'destination': 'Pontianak',
#    'locode': 'IDPNK',
#    'portCountry': 'Indonesia'},
#   'geoDetails': {'timeOfATChange': '2021-08-20T01:07:25Z',
#    'status': 'waiting'}},
#  ...]

# %%
count = 0
set_values = set([])
for item in data_list:
    try:
        value = item['geoDetails']['currentAnchorage']
        set_values.add(value)
#         print(value)
        count += 1
    except:
        pass
        
print(list(set_values))
print(count)
# aisStatic
# aisPosition
# aisVoyage
# voyageDetails
# geoDetails
# vesselDetails
# msg27
# Out:
# ['Yantai Anchorage', 'Jakarta Anchorage', 'Zhanjiang Outer Anchorage', 'Plymouth Anchorage', 'Arica Anchorage', 'Balikpapan Outer Anchorage', 'Owendo Anchorage', 'Zhoushan Anchorage', 'Prelude LNG anchorage', 'Muara Satui Anchorage', 'Arzew El-Djedid Anchorage', 'Kilyos Anchorage', 'Felixstowe Anchorage', 'Ashdod Anchorage', 'Gwangyang Port Anchorage', 'Mokpo Anchorage', 'Xiamen Anchorage', 'Fortaleza Anchorage', 'Sandakan Anchorage', 'Shidao Anchorage', 'Shibushi Anchorage', 'Semarang Anchorage', 'Dar es Salaam Anchorage', 'Limassol Anchorage', 'Caldera Anchorage', 'Jiangyinzhen Anchorage', 'Barcelona Anchorage', 'Shijingzhen Anchorage', 'Ravenna Anchorage', 'Cotonou Anchorage', 'Yokohama Anchorage', 'Fos Anchorage', 'Astoria Anchorage', 'Civitavecchia Anchorage', 'Jebel Ali Anchorage', 'Abidjan Anchorage', 'Port Klang Anchorage', 'Pengerang Anchorage', 'Sagunto Anchorage', 'Tanger-Med Anchorage', 'Gibraltar Anchorage West', 'Mizushima Anchorage', 'Takoradi Anchorage', 'Huelva Anchorage', 'New Orleans Anchorage', 'Liepaja Anchorage', 'Foulness Anchorage', 'Maji Shan Anchorage', 'Nagoya Anchorage', 'Umm Said Anchorage', 'Castellon Anchorage', 'Balikpapan Inner Anchorage', 'Caobeidian Anchorage', 'Cam Pha Anchorage', 'RTM Anchorage N', 'Whyalla Anchorage', 'Puerto Cabello Anchorage', 'Tapti Anchorage', 'Kribi Anchorage', 'Kolkata River Anchorage', 'Wikinger Offshore', 'Pozzuoli Anchorage', 'Port Hedland Anchorage', 'Asaluyeh Anchorage', 'Poti Anchorage', 'Shiogama Anchorage', 'Port Kamsar Anchorage', 'Ryotsu Anchorage', 'Yuzhne Anchorage', 'La Brea Anchorage', 'La Spezia Anchorage', 'Bristol Channel', 'Brindisi Anchorage', 'Mumbai Anchorage', 'Port Arthur Anchorage', 'Kuwait Anchorage', 'Hong Kong Anchorage', 'Cebu Anchorage', 'Hui Zhou Anchorage', 'Algeciras Anchorage (Norte)', 'Skagen Anchorage', 'Ishinomaki Anchorage', 'Port of Spain Anchorage', 'Sines Anchorage', 'Savannah Anchorage', 'Falmouth Anchorage', 'Belem Anchorage', 'Chennai Anchorage', 'Iwakuni Anchorage', 'Ningde Anchorage', 'Saint-Nazaire Anchorage', 'Salvador BRA Anchorage', 'Vancouver Anchorage', 'Rijeka Anchorage', 'Vostochnyy Anchorage', 'Fangchenggang Anchorage', 'Qingdao North Anchorage', 'Tai Chung Anchorage', 'IJmuiden Anchorage', 'Incheon Anchorage', 'Manila Anchorage', 'Saint Eustasius Anchorage', 'Kashima Anchorage', 'Dandong Anchorage', 'Montevideo Anchorage', 'Puerto Cortes Anchorage', 'Marmara West Anchorage', 'Singapur East Anchorage', 'Galle Anchorage', 'Veracruz Anchorage', 'Sarroch Anchorage', 'Gove Anchorage', 'Katwijk Anchorage', 'Antibes Anchorage', 'Onahama Anchorage', 'Ust-Luga Anchorage', 'Kochi (Cochin) Anchorage', 'Paranagua Anchorage', 'Cape Lambert Anchorage', 'Yingkou Anchorage', 'Takuma Anchorage', 'Hekou Anchorage', 'Manjung Anchorage', 'Quynhon Anchorage', 'Kingston Anchorage', 'Khalifa Anchorage', 'Balongan Anchorage', 'Ube Anchorage', 'Saleef Anchorage', 'Cartagena (Spain) Anchorage', 'Shakhtersk', 'Mundra Anchorage', 'Nouadhibou Anchorage', 'Mobile Anchorage', 'Marsa Bashayer Anchorage', 'Mersin Anchorage', 'Rio Anchorage', 'Santos Anchorage', 'Westhinder', 'Manzanillo Anchorage', 'Santa Cruz Anchorage', 'Quanzhou Anchorage', 'Zhuhai Anchorage', 'Esmeraldas Anchorage', 'Guayaquil Anchorage', 'Temryuk Anchorage', 'Pecem Anchorage', 'Sousse Anchorage', 'Longkou Anchorage', 'Ciudad del Carmen Anchorage', 'Yangshan Anchorage', 'Firth of Forth Anchorage', 'Maoming Anchorage', 'Odessa Anchorage', 'Ketapang Anchorage', 'Malakka Anchorage', 'Escravos Anchorage', 'Punta Arenas Anchorage', 'Adelaide Anchorage', 'Ilo Anchorage', 'Al Manamah Anchorage', 'Singapur South Anchorage', 'Le Havre Anchorage', 'Gadani Anchorage', 'Vitoria Anchorage', 'Gladstone Anchorage', 'Singapore West Anchorage', 'Zhapu Anchorage', 'Conakry Anchorage', 'Augusta Anchorage', 'RTM Anchorage S', 'Vigo Anchorage', 'Saint Georges Anchorage', 'Pascagoula Anchorage', 'Mumbai Sea Anchorage', 'Daesan Anchorage', 'Fukuoka Anchorage', 'Frederikshavn Anchorage', 'Baku Inne ...
# 5264

# %%
aisStatic: 7043
aisPosition: 7043
aisVoyage: 7043
voyageDetails: 4380
geoDetails: 7043
vesselDetails: 0
msg27: 0
