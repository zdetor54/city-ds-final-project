# %%
"""
lookup candidate entities and classes
"""
import os
import pandas as pd
import sys
import argparse
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext

current_path = os.getcwd()
parser = argparse.ArgumentParser()
parser.add_argument(
    '--input_dir',
    type=str,
    default=os.path.join(current_path, 'data'),
    help='Directory of input/output')
parser.add_argument(
    '--file_type',
    type=str,
    default='csv',
    help='File type')
parser.add_argument(
    '--lookup_results_rank',
    type=int,
    default=5,
    help='File type')

FLAGS, unparsed = parser.parse_known_args()
# if not os.path.exists(FLAGS.input_dir):
#     os.mkdir(FLAGS.input_dir)

# %%
# Get all the csv files from the input directory
def get_data_files(data_folder):
    """
    A function used to get all the csv files from the input directory
    ...

    Attributes
    ----------
    data_folder : str
        the folder within  the working directory where the data is located
    """

    files = [] # a list of all filenames, including file extensions, that contain data
    csv_files = [] # same list as above but without the file extension

    # Get the list of files
    files = [f for f in os.listdir(FLAGS.input_dir+data_folder) if os.path.isfile(os.path.join(FLAGS.input_dir+data_folder, f))]
    csv_files = [f.replace(".csv","") for f in os.listdir(FLAGS.input_dir+data_folder) if os.path.isfile(os.path.join(FLAGS.input_dir+data_folder, f))]
    
    return csv_files

def get_target_cta_columns(target_config_file, data_folder, csv_files, filter_col = True):
    """
    A function used to get which columns from the csv files need to be considered for the CTA. This is a subset of the file columns ignoring anything that is not an entity
    ...

    Attributes
    ----------
    target_config_file : str
        the file that contains the target column indices for each file
    csv_files : list
        the list of csv files that have the tabular data
    filter_col : boolean
        a flag to indicate whether we should narrow down the reading of the columns to only those targeted for the CTA task
    """
   
    target_col_file = os.path.join(FLAGS.input_dir+data_folder, target_config_file)
    df_target_col = pd.read_csv(target_col_file,header=None, names=['filename','column_index'])
    
    # filter to only those files that are included in the csv_files
    df_target_col = df_target_col.loc[df_target_col['filename'].isin(csv_files)]
    
    # collapse all rows pertaining to the same file into one key value pair. The key is the filename and the value is the list with the column indices that should be considered
    # dict_target = {'CTRL_DBP_GEO_european_countries_capital_populated_cities': [0, 1, 2]}
    dict_target = dict()
    
    for index,row in df_target_col.iterrows():
        
        # is this is the first row with this file create the key
        if row['filename'] not in dict_target:
            dict_target[row['filename']]= []
            
        # append the new target column to the target column list for that file
        if filter_col:
            dict_target[row['filename']].append(int(row['column_index']))
    
    return dict_target

def get_ground_truth(file, folder, csv_files):
    """
    A function used to get the ground truths as provided in the setup
    ...

    Attributes
    ----------
    file : str
        the file that contains the ground truth for the class of each column in each file
    folder : str
        the folder that contains the ground truth file
    csv_files : list
        the list of csv files that have the tabular data
    """
    
    dbo_prefix = 'http://dbpedia.org/ontology/'
   
    filepath = os.path.join(FLAGS.input_dir+folder, file)
    df_ground_truth = pd.read_csv(filepath,header=None, names=['filename','column_index', 'class'])
    
    # filter to only those files that are included in the csv_files
    df_ground_truth = df_ground_truth.loc[df_ground_truth['filename'].isin(csv_files)]
    
    # collapse all rows pertaining to the same file into one key value pair. The key is the filename and the value is the list with the column indices that should be considered
    # dict_target = {'CTRL_DBP_GEO_european_countries_capital_populated_cities': [0, 1, 2]}
    dict_gt = dict()
    
    for index,row in df_ground_truth.iterrows():
        
        # is this is the first row with this file create the key
        if row['filename'] not in dict_gt:
            dict_gt[row['filename']]= dict()
            
        # append the new target column to the target column list for that file
        dict_gt[row['filename']][int(row['column_index'])] = row['class'].split(dbo_prefix)[1]
    
    return dict_gt

def read_data(data_folder, dict_target_col, has_header_row = False):
    """
    A function used to read the data from the csvs in the data_folder only considering the columns that are in the dict_target_col
    ...

    Attributes
    ----------
    folder : str
        the folder that contains the csvs with the tabular data
    dict_target_col : dictionary
        a dictionary with csv filenames as the key and an array of relevant column indices as a value
    has_header_row : boolean
        a flag to indicate whether the first row in the csv files needs to be skipped as it is a header
    """
    data = list()

    for file in dict_target_col:
        element = dict()
        element['filename'] = file
        df_data = pd.DataFrame()
        df_title = pd.DataFrame()



        filename = file + '.' + FLAGS.file_type
        tab_data_file = os.path.join(FLAGS.input_dir + data_folder, filename)

        # read the file data in a dataframe. Also read the column titles if we need to use them
        if len(dict_target_col[file])>0:
            if has_header_row:
                df_data = pd.read_csv(tab_data_file,header=None, skiprows=[0], usecols=dict_target_col[file])
                df_title = pd.read_csv(tab_data_file,header=None, usecols=dict_target_col[file], nrows = 1)
            else:
                df_data = pd.read_csv(tab_data_file,header=None, usecols=dict_target_col[file])
        else:
            if has_header_row:
                df_data = pd.read_csv(tab_data_file,header=None, skiprows=[0])
                df_title = pd.read_csv(tab_data_file,header=None, nrows = 1)
            else:
                df_data = pd.read_csv(tab_data_file,header=None)

        # add the column headers to the data dictionary
        try:
            element['column_titles'] = list(df_title.iloc[0,:])
        except:
            pass

        file_element = dict()
        for column in df_data.columns:
            file_element[column] = list(set(df_data[column]))
        element['data'] = file_element

        element['dataframe'] = df_data    
        data.append(element)
    
    return data

# %% [markdown]
# ### Background Setup
#
# As part of this initial step we will need to load the data we are going to process as well as the targets we are trying to meet. The data is located in the data folder as follows
# - round_1:
#     - gt: the expected outcome (ground truth)
#     - tables: the tabular data
#     - targets: the columns / cells we need to consider for the CTA/CEA
# ----
# Step 1: Get a list of all the csv files in the data folder

# %%
# Get the list of csv files with tabular data
csv_files = get_data_files('\\round_1\\tables')
# csv_files = csv_files[:1]
csv_files
# Out:
# ['10579449_0_1681126353774891032',
#  '11833461_1_3811022039809817402',
#  '13719111_1_5719401842463579519',
#  '14067031_0_559833072073397908',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5',
#  '1438042986423_95_20150728002306-00329-ip-10-236-191-2_805336391_10',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2',
#  '14380604_4_3329235705746762392',
#  '16767252_0_2409448375013995751',
#  '20135078_0_7570343137119682530',
#  '21245481_0_8730460088443117515',
#  '21362676_0_6854186738074119688',
#  '22864497_0_8632623712684511496',
#  '24036779_0_5608105867560183058',
#  '25404227_0_2240631045609013057',
#  '26310680_0_5150772059999313798',
#  '28086084_0_3127660530989916727',
#  '29414811_12_251152470253168163',
#  '29414811_13_8724394428539174350',
#  '29414811_2_4773219892816395776',
#  '29414811_6_8221428333921653560',
#  '33401079_0_9127583903019856402',
#  '34041816_1_4749054164534706977',
#  '35188621_0_6058553107571275232',
#  '36102169_0_7739454799295072814',
#  '37856682_0_6818907050314633217',
#  '38428277_0_1311643810102462607',
#  '39107734_2_2329160387535788734',
#  '39173938_0_7916056990138658530',
#  '39650055_5_7135804139753401681',
#  '39759273_0_1427898308030295194',
#  '40534006_0_4617468856744635526',
#  '41336118_0_4331895026409635103',
#  '41480166_0_6681239260286218499',
#  '43237185_1_3636357855502246981',
#  '45073662_0_3179937335063201739',
#  '46671561_0_6122315295162029872',
#  '50245608_0_871275842592178099',
#  '50270082_0_444360818941411589',
#  '52299421_0_4473286348258170200',
#  '53822652_0_5767892317858575530',
#  '53989675_0_8697482470743954630',
#  '54719588_0_8417197176086756912',
#  '58891288_0_1117541047012405958',
#  '60319454_0_3938426910282115527',
#  '63450419_0_8012592961815711786',
#  '66009064_0_9148652238372261251',
#  '69537082_0_7789694313271016902',
#  '69881946_0_1105130426898457358',
#  '71840765_0_6664391841933033844',
#  '75367212_2_2745466355267233390',
#  '77694908_0_6083291340991074532',
#  '80588006_0_6965325215443683359',
#  '84548468_0_5955155464119382182',
#  '84575189_0_6365692015941409487',
#  '8468806_0_4382447409703007384',
#  '88523363_0_8180214313099580515',
#  '90196673_0_5458330029110291950',
#  '91959037_0_7907661684242014480',
#  '9475172_1_1023126399856690702',
#  '9567241_0_5666388268510912770',
#  '9834884_0_3871985887467090123',
#  '99070098_0_2074872741302696997']

# %% [markdown]
# Step 2: Get the columns we need to consider for the CTA task

# %%
# Get the columns we need to consider for the CTA task
dict_target_col = get_target_cta_columns('CTA_Round1_Targets.csv', '\\round_1\\targets', csv_files,True)
dict_target_col
# Out:
# {'58891288_0_1117541047012405958': [1, 3],
#  '8468806_0_4382447409703007384': [1, 2],
#  '50245608_0_871275842592178099': [0, 3, 4],
#  '14067031_0_559833072073397908': [1, 7, 5, 0],
#  '39759273_0_1427898308030295194': [1, 3],
#  '14380604_4_3329235705746762392': [1, 2],
#  '20135078_0_7570343137119682530': [3, 1],
#  '29414811_6_8221428333921653560': [1, 4, 2],
#  '34041816_1_4749054164534706977': [2, 1],
#  '29414811_2_4773219892816395776': [1, 4, 2],
#  '99070098_0_2074872741302696997': [1],
#  '35188621_0_6058553107571275232': [3, 1],
#  '43237185_1_3636357855502246981': [3, 0, 2],
#  '46671561_0_6122315295162029872': [0, 1],
#  '11833461_1_3811022039809817402': [0, 1],
#  '21245481_0_8730460088443117515': [1, 0],
#  '38428277_0_1311643810102462607': [3, 1],
#  '13719111_1_5719401842463579519': [0],
#  '77694908_0_6083291340991074532': [1, 3],
#  '88523363_0_8180214313099580515': [0, 2],
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2': [0],
#  '25404227_0_2240631045609013057': [3, 1],
#  '9475172_1_1023126399856690702': [1],
#  '60319454_0_3938426910282115527': [0],
#  '52299421_0_4473286348258170200': [1],
#  '37856682_0_6818907050314633217': [0],
#  '29414811_13_8724394428539174350': [2, 4, 1],
#  '33401079_0_9127583903019856402': [0],
#  '26310680_0_5150772059999313798': [1, 0],
#  '10579449_0_1681126353774891032': [1],
#  '84548468_0_5955155464119382182': [3, 1],
#  '63450419_0_8012592961815711786': [1],
#  '39107734_2_2329160387535788734': [1, 2],
#  '29414811_12_251152470253168163': [4, 2, 1],
#  '91959037_0_7907661684242014480': [1],
#  '75367212_2_2745466355267233390': [1, 2, 0],
#  '84575189_0_6365692015941409487': [2],
#  '40534006_0_4617468856744635526': [1],
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5': [0],
#  '22864497_0_8632623712684511496': [0, 1],
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2': [0],
#  '28086084_0_3127660530989916727': [0],
#  '9834884_0_3871985887467090123': [1, 2],
#  '69881946_0_1105130426898457358': [1, 3],
#  '39650055_5_7135804139753401681': [1],
#  '16767252_0_2409448375013995751': [3, 1],
#  '71840765_0_6664391841933033844': [0],
#  '36102169_0_7739454799295072814': [1, 2],
#  '45073662_0_3179937335063201739': [1],
#  '53822652_0_5767892317858575530': [3, 1],
#  '39173938_0_7916056990138658530': [1, 3],
#  '21362676_0_6854186738074119688': [3, 1],
#  '80588006_0_6965325215443683359': [1],
#  '90196673_0_5458330029110291950': [0],
#  '53989675_0_8697482470743954630': [0],
#  '66009064_0_9148652238372261251': [0, 2],
#  '50270082_0_444360818941411589': [1],
#  '24036779_0_5608105867560183058': [0, 5],
#  '41336118_0_4331895026409635103': [0],
#  '54719588_0_8417197176086756912': [3, 5, 4],
#  '41480166_0_6681239260286218499': [0],
#  '9567241_0_5666388268510912770': [1],
#  '69537082_0_7789694313271016902': [1]}

# %% [markdown]
# Step 3: Get the ground truth for all columns in the set of csv files

# %%
ground_truth = get_ground_truth('CTA_Round1_gt.csv', '\\round_1\\gt', csv_files)
ground_truth
# Out:
# {'58891288_0_1117541047012405958': {1: 'Film', 3: 'Person'},
#  '8468806_0_4382447409703007384': {1: 'Lake', 2: 'Country'},
#  '50245608_0_871275842592178099': {0: 'Film', 3: 'Person', 4: 'Writer'},
#  '14067031_0_559833072073397908': {1: 'Language',
#   7: 'Currency',
#   5: 'City',
#   0: 'Country'},
#  '39759273_0_1427898308030295194': {1: 'Film', 3: 'Person'},
#  '14380604_4_3329235705746762392': {1: 'Company', 2: 'PopulatedPlace'},
#  '20135078_0_7570343137119682530': {3: 'Person', 1: 'Film'},
#  '29414811_6_8221428333921653560': {1: 'VideoGame', 4: 'Company', 2: 'Genre'},
#  '34041816_1_4749054164534706977': {2: 'City', 1: 'Airport'},
#  '29414811_2_4773219892816395776': {1: 'VideoGame', 4: 'Company', 2: 'Genre'},
#  '99070098_0_2074872741302696997': {1: 'Mountain'},
#  '35188621_0_6058553107571275232': {3: 'Person', 1: 'Film'},
#  '43237185_1_3636357855502246981': {3: 'Scientist',
#   0: 'Scientist',
#   2: 'EducationalInstitution'},
#  '46671561_0_6122315295162029872': {0: 'VideoGame', 1: 'Genre'},
#  '11833461_1_3811022039809817402': {0: 'VideoGame', 1: 'Company'},
#  '21245481_0_8730460088443117515': {1: 'Lake', 0: 'AdministrativeRegion'},
#  '38428277_0_1311643810102462607': {3: 'Person', 1: 'Film'},
#  '13719111_1_5719401842463579519': {0: 'Bird'},
#  '77694908_0_6083291340991074532': {1: 'Film', 3: 'Person'},
#  '88523363_0_8180214313099580515': {0: 'Plant', 2: 'Eukaryote'},
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2': {0: 'Mountain'},
#  '25404227_0_2240631045609013057': {3: 'Person', 1: 'Film'},
#  '9475172_1_1023126399856690702': {1: 'TelevisionShow'},
#  '60319454_0_3938426910282115527': {0: 'Animal'},
#  '52299421_0_4473286348258170200': {1: 'Country'},
#  '37856682_0_6818907050314633217': {0: 'AdministrativeRegion'},
#  '29414811_13_8724394428539174350': {2: 'Genre', 4: 'Company', 1: 'VideoGame'},
#  '33401079_0_9127583903019856402': {0: 'Person'},
#  '26310680_0_5150772059999313798': {1: 'Currency', 0: 'Country'},
#  '10579449_0_1681126353774891032': {1: 'Newspaper'},
#  '84548468_0_5955155464119382182': {3: 'Person', 1: 'Film'},
#  '63450419_0_8012592961815711786': {1: 'Plant'},
#  '39107734_2_2329160387535788734': {1: 'Airport', 2: 'City'},
#  '29414811_12_251152470253168163': {4: 'Company', 2: 'Genre', 1: 'VideoGame'},
#  '91959037_0_7907661684242014480': {1: 'VideoGame'},
#  '75367212_2_2745466355267233390': {1: 'Company',
#   2: 'Company',
#   0: 'VideoGame'},
#  '84575189_0_6365692015941409487': {2: 'AcademicJournal'},
#  '40534006_0_4617468856744635526': {1: 'Wrestler'},
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5': {0: 'PoliticalParty'},
#  '22864497_0_8632623712684511496': {0: 'VideoGame', 1: 'Company'},
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2': {0: 'Cricketer'},
#  '28086084_0_3127660530989916727': {0: 'Saint'},
#  '9834884_0_3871985887467090123': {1: 'Museum', 2: 'Country'},
#  '69881946_0_1105130426898457358': {1: 'Film', 3: 'Person'},
#  '39650055_5_7135804139753401681': {1: 'Company'},
#  '16767252_0_2409448375013995751': {3: 'Person', 1: 'Film'},
#  '71840765_0_6664391841933033844': {0: 'Lake'},
#  '36102169_0_7739454799295072814': {1: 'Company', 2: 'VideoGame'},
#  '45073662_0_3179937335063201739': {1: 'BaseballPlayer'},
#  '53822652_0_5767892317858575530': {3: 'Person', 1: 'Film'},
#  '39173938_0_7916056990138658530': {1: 'Film', 3: 'Person'},
#  '21362676_0_6854186738074119688': {3: 'Person', 1: 'Film'},
#  '80588006_0_6965325215443683359': {1: 'Newspaper'},
#  '90196673_0_5458330029110291950': {0: 'Animal'},
#  '53989675_0_8697482470743954630': {0: 'Lake'},
#  '66009064_0_9148652238372261251': {0: 'BaseballPlayer', 2: 'SportsTeam'},
#  '50270082_0_444360818941411589': {1: 'BaseballPlayer'},
#  '24036779_0_5608105867560183058': {0: 'Country', 5: 'GovernmentType'},
#  '41336118_0_4331895026409635103': {0: 'Company'},
#  '54719588_0_8417197176086756912': {3: 'Film', 5: 'Person', 4: 'Country'},
#  '41480166_0_6681239260286218499': {0: 'Saint'},
#  '9567241_0_5666388268510912770': {1: 'Newspaper'},
#  '69537082_0_7789694313271016902': {1: 'Country'}}

# %% [markdown]
# # Load Data
#
# The next step is to load the data from the csv files. We load the data as an array of dictionaries.
# Each dictionary will have the following structure:<br>
# {<br>
# <blockquote>
# <strong>'filename':</strong> '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5',<br>
# <strong>'column_titles'</strong>: ['Party'],<br>
# <strong>'data'</strong>: <br>
#     {<br>
#     <blockquote>
#         <strong>0:</strong> ['PC', 'Lib-Dem','SNP','UKIP','Labour','BNP','Conservative','Green']<br>
#     </blockquote>
#         },<br>
#
# <strong>'dataframe':</strong>               0
#  0  Conservative
#  1        Labour
#  2       Lib-Dem
#  3           SNP
#  4            PC
#  5         Green
#  6           BNP
#  7          UKIP<br>
# </blockquote>
#  }

# %%
data = read_data('\\round_1\\tables', dict_target_col,True)

# %%
import requests
import xml.etree.ElementTree as ET
import time

def retrieve_dbpedia_classes (query_string, max_hits = 5):
    web_api = 'http://lookup.dbpedia.org/api/search/KeywordSearch?MaxHits=%s&QueryString=%s'
    dbo_prefix = 'http://dbpedia.org/ontology/'
    dbp_prefix = 'http://dbpedia.org/resource/'
    entity_classes = dict()
    try:
        lookup_url = web_api % (max_hits, query_string)
#         print(lookup_url)
        lookup_res = requests.get(lookup_url)
        root = ET.fromstring(lookup_res.content)
        i=0
        for child in root:
            i+=1
#             print("\n")
            entity = child[1].text.split(dbp_prefix)[1]
#             print(entity)
            classes = list()
            for cc in child[3]:
                cls_URI = cc[1].text
#                 print(cls_URI)
                if dbo_prefix in cls_URI:
                    classes.append((cls_URI.split(dbo_prefix)[1]))
            if len(classes)>0:
                entity_classes[entity] = dict()
                entity_classes[entity]['rank'] = i
                entity_classes[entity]['candidate_classes'] = classes
    except UnicodeDecodeError:
        pass
    return entity_classes

# %% [markdown]
# ## Lookup cell_values
#
# With the data loaded in the *data* dictionary the next step is to lookup the cell values in the DBpedia endpoint and get the canidate classes and entities.
# Each cell value is only looked up once, however we still keep track of any column it might have appeared in as well as all candidate entities and classes it may have matched to.
#
# For this level of analysis we are flexible to store the 5 top lookup results for each cell value (default value for FLAGS.lookup_results_rank).
# We will then assess the number of classifiers we need to train later and perhaps filter out any candidate classes that only appeared in lower ranks.
#
# The outcome of the lookup is stored in the *cell_values* dictionary as follows:
#
# {<strong>"Madagascar":</strong><br>
# {
# <blockquote><strong>"location":</strong> [("14067031_0_559833072073397908",0)]
#             , <br><strong>"candidate_entities":</strong><br>
#                         {
#                             <blockquote><strong>"Madagascar":</strong> <br>{<blockquote><strong>"rank":</strong> 1,<br> <strong>"candidate_classes":</strong> ["Place", "Country", "PopulatedPlace", "Location"]</blockquote>}, <br>
#                             <strong>"Antananarivo":</strong> <br> {<blockquote><strong>"rank":</strong> 3,<br> <strong>"candidate_classes":</strong> ["Settlement", "Place", "PopulatedPlace", "Location"]</blockquote>}, <br>
#                             <strong>"List_of_Madagascar_(franchise)_characters":</strong> <br> {<blockquote><strong>"rank":</strong> 4,<br> <strong>"candidate_classes":</strong> ["FictionalCharacter", "Agent"]</blockquote>},<br>
#                             <strong>"Madagascar_national_football_team"</strong> <br> {<blockquote><strong>"rank":</strong> 5,<br> <strong>"candidate_classes":</strong> ["Organisation", "SoccerClub", "Agent", "SportsClub"]</blockquote>}<br>
# </blockquote>}<br>
# </blockquote>},<br>
#
#  <strong>"South Africa":</strong> {...},<br>
#   ...<br>
#  }

# %%
cell_values = dict()
i = 0

from IPython.display import clear_output

size = 0
for file_i in range(len(data)):
    for col in data[file_i]['data']:
        for line_j in range(len(data[file_i]['data'][col])):
            size+=1
            
start_time = time.time()

# from tqdm import tqdm
for file_i in range(len(data)):
#     print(data[file_i])
    filename = data[file_i]['filename']
    for col in data[file_i]['data']:
        column_index = col
#         print(col)
#         print(data[file_i]['data'][col])
        for line_j in range(len(data[file_i]['data'][col])):
            i+=1
            cell_value = data[file_i]['data'][col][line_j]
            clear_output(wait=True)
            print('{0:.2f}'.format(100*i/size,2),'-->',filename, ": ",cell_value)
            if cell_value in cell_values.keys():
                cell_values[cell_value]['location'].append((filename,column_index))
            else:
                cell_values[cell_value] = dict()
                cell_values[cell_value]['location'] = [(filename,column_index)]
                try:
                    cell_values[cell_value]['candidate_entities'] = retrieve_dbpedia_classes(cell_value.replace("[",'').replace("]",''),FLAGS.lookup_results_rank)
                except:
                    cell_values[cell_value]['candidate_entities'] = retrieve_dbpedia_classes(cell_value,FLAGS.lookup_results_rank)
                
end_time = time.time()

print(f"{int(end_time - start_time)//60} min and {int((end_time - start_time)%60)} seconds Elapsed")
# Out:
# 100.00 --> 69537082_0_7789694313271016902 :  Northern Mariana Islands
# 88 min and 41 seconds Elapsed

# %%
# cell_values

# %%
import json

# Store the dictionary with the lookup results for each cell value in the tabular data
with open('cell_values.json', 'w') as fp:
    json.dump(cell_values, fp)

# %%
retrieve_dbpedia_classes('Steven Spielberg',FLAGS.lookup_results_rank)
# Out:
# {'Taken_(miniseries)': {'rank': 5,
#   'candidate_classes': ['TelevisionShow', 'Work']}}

# %%
# Load the dictionary with the lookup results for each cell value in the tabular data
with open('cell_values.json') as json_file:
    loaded_cell_values = json.load(json_file)

# %%
# dict_target_col

filename = '58891288_0_1117541047012405958'
temp = {'58891288_0_1117541047012405958': [1, 3]}
temp_cell_values = dict()
temp_cell_values['The Bridge on the River Kwai'] = cell_values['The Bridge on the River Kwai'] 

temp_cell_values
# Out:
# {'The Bridge on the River Kwai': {'location': [('58891288_0_1117541047012405958',
#     1),
#    ('77694908_0_6083291340991074532', 1),
#    ('25404227_0_2240631045609013057', 1),
#    ('16767252_0_2409448375013995751', 1)],
#   'candidate_entities': {'The_Bridge_over_the_River_Kwai': {'rank': 1,
#     'candidate_classes': ['Book', 'WrittenWork', 'Work']},
#    'Kanchanaburi_Province': {'rank': 3,
#     'candidate_classes': ['AdministrativeRegion',
#      'Place',
#      'PopulatedPlace',
#      'Location',
#      'Region']},
#    'Balu_Mahendra': {'rank': 4, 'candidate_classes': ['Person', 'Agent']},
#    'A._B._Raj': {'rank': 5, 'candidate_classes': ['Person', 'Agent']}}}}

# %%
dict_col_candidate_classes = dict()
threshold = 3

for filename in dict_target_col: #later replace with dict_target_col
    dict_col_candidate_classes[filename] = dict()
    for i in dict_target_col[filename]:
        dict_col_candidate_classes[filename][i] = []
#     print(key)
    for cell_value in cell_values:
        try:
            column_index = dict(cell_values[cell_value]['location'])[filename]
            for candidate_entity in cell_values[cell_value]['candidate_entities']:
#                 print(candidate_entity)
                rank = cell_values[cell_value]['candidate_entities'][candidate_entity]['rank']
                if rank <= threshold:
                    for candidate_class in cell_values[cell_value]['candidate_entities'][candidate_entity]['candidate_classes']:
                        dict_col_candidate_classes[filename][column_index].append((candidate_class, candidate_entity, cell_value,rank))
                
            dict_col_candidate_classes[filename][column_index]
#             print('found')
        except:
            pass
#             print('not found')

# %%
cell_values['Steven Spielberg']
# Out:
# {'location': [('58891288_0_1117541047012405958', 3),
#   ('39759273_0_1427898308030295194', 3),
#   ('20135078_0_7570343137119682530', 3),
#   ('35188621_0_6058553107571275232', 3),
#   ('38428277_0_1311643810102462607', 3),
#   ('77694908_0_6083291340991074532', 3),
#   ('25404227_0_2240631045609013057', 3),
#   ('84548468_0_5955155464119382182', 3),
#   ('69881946_0_1105130426898457358', 3),
#   ('53822652_0_5767892317858575530', 3),
#   ('21362676_0_6854186738074119688', 3)],
#  'candidate_entities': {'Taken_(miniseries)': {'rank': 5,
#    'candidate_classes': ['TelevisionShow', 'Work']}}}

# %%
dict_target_col['20135078_0_7570343137119682530']
# Out:
# [3, 1]

# %%
dict_col_candidate_classes['20135078_0_7570343137119682530'][3]
# Out:
# [('Person', 'Jean_Renoir', 'Jean Renoir', 1),
#  ('Agent', 'Jean_Renoir', 'Jean Renoir', 1),
#  ('Film', 'The_Little_Theatre_of_Jean_Renoir', 'Jean Renoir', 3),
#  ('Work', 'The_Little_Theatre_of_Jean_Renoir', 'Jean Renoir', 3),
#  ('Person', 'Nicholas_Ray', 'Nicholas Ray', 1),
#  ('Agent', 'Nicholas_Ray', 'Nicholas Ray', 1),
#  ('Politician', 'Nicholas_Winterton', 'Nicholas Ray', 2),
#  ('Person', 'Nicholas_Winterton', 'Nicholas Ray', 2),
#  ('Agent', 'Nicholas_Winterton', 'Nicholas Ray', 2),
#  ('MusicalArtist', 'Nicholas_Furlong_(musician)', 'Nicholas Ray', 3),
#  ('Person', 'Nicholas_Furlong_(musician)', 'Nicholas Ray', 3),
#  ('Artist', 'Nicholas_Furlong_(musician)', 'Nicholas Ray', 3),
#  ('Agent', 'Nicholas_Furlong_(musician)', 'Nicholas Ray', 3),
#  ('Person', 'Alfred_Hitchcock', 'Alfred Hitchcock', 1),
#  ('Agent', 'Alfred_Hitchcock', 'Alfred Hitchcock', 1),
#  ('TelevisionShow', 'Alfred_Hitchcock_Presents', 'Alfred Hitchcock', 2),
#  ('Work', 'Alfred_Hitchcock_Presents', 'Alfred Hitchcock', 2),
#  ('Person', 'Martin_Scorsese', 'Martin Scorsese', 1),
#  ('Agent', 'Martin_Scorsese', 'Martin Scorsese', 1),
#  ('Album',
#   'Martin_Scorsese_Presents_the_Blues:_Jimi_Hendrix',
#   'Martin Scorsese',
#   2),
#  ('MusicalWork',
#   'Martin_Scorsese_Presents_the_Blues:_Jimi_Hendrix',
#   'Martin Scorsese',
#   2),
#  ('Work',
#   'Martin_Scorsese_Presents_the_Blues:_Jimi_Hendrix',
#   'Martin Scorsese',
#   2),
#  ('Person', 'Howard_Hawks', 'Howard Hawks', 1),
#  ('Agent', 'Howard_Hawks', 'Howard Hawks', 1),
#  ('Organisation', 'Howard_College', 'Howard Hawks', 2),
#  ('University', 'Howard_College', 'Howard Hawks', 2),
#  ('EducationalInstitution', 'Howard_College', 'Howard Hawks', 2),
#  ('Agent', 'Howard_College', 'Howard Hawks', 2),
#  ('Person', 'Sergei_Eisenstein', 'Sergei M. Eisenstein', 1),
#  ('Agent', 'Sergei_Eisenstein', 'Sergei M. Eisenstein', 1),
#  ('Organisation', 'Mosfilm', 'Sergei M. Eisenstein', 2),
#  ('Company', 'Mosfilm', 'Sergei M. Eisenstein', 2),
#  ('Agent', 'Mosfilm', 'Sergei M. Eisenstein', 2),
#  ('Person', 'Vsevolod_Pudovkin', 'Sergei M. Eisenstein', 3),
#  ('Agent', 'Vsevolod_Pudovkin', 'Sergei M. Eisenstein', 3),
#  ('Person', 'Danny_Boyle', 'Danny Boyle', 1),
#  ('Agent', 'Danny_Boyle', 'Danny Boyle', 1),
#  ('Person', 'Christopher_Eccleston', 'Danny Boyle', 3),
#  ('Agent', 'Christopher_Eccleston', 'Danny Boyle', 3),
#  ('Person', 'Frank_Darabont', 'Frank Darabont', 1),
#  ('Agent', 'Frank_Darabont', 'Frank Darabont', 1),
#  ('TelevisionSeason', 'The_Walking_Dead_(season_2)', 'Frank Darabont', 2),
#  ('Work', 'The_Walking_Dead_(season_2)', 'Frank Darabont', 2),
#  ('TelevisionSeason', 'The_Walking_Dead_(season_1)', 'Frank Darabont', 3),
#  ('Work', 'The_Walking_Dead_(season_1)', 'Frank Darabont', 3),
#  ('Person', 'Woody_Allen', 'Woody Allen', 1),
#  ('Agent', 'Woody_Allen', 'Woody Allen', 1),
#  ('MusicalArtist', 'Allen_Woody', 'Woody Allen', 2),
#  ('Person', 'Allen_Woody', 'Woody Allen', 2),
#  ('Artist', 'Allen_Woody', 'Woody Allen', 2),
#  ('Agent', 'Allen_Woody', 'Woody Allen', 2),
#  ('Person', 'Terry_Gilliam', 'Terry Gilliam', 1),
#  ('Agent', 'Terry_Gilliam', 'Terry Gilliam', 1),
#  ('Person', 'Robert_Wise', 'Robert Wise', 1),
#  ('Agent', 'Robert_Wise', 'Robert Wise', 1),
#  ('Politician', 'Bob_Wise', 'Robert Wise', 2),
#  ('Person', 'Bob_Wise', 'Robert Wise', 2),
#  ('Agent', 'Bob_Wise', 'Robert Wise', 2),
#  ('Person', 'Robert_Parker_(wine_critic)', 'Robert Wise', 3),
#  ('Writer', 'Robert_Parker_(wine_critic)', 'Robert Wise', 3),
#  ('Agent', 'Robert_Parker_(wine_critic)', 'Robert Wise', 3),
#  ('Person', 'Jean-Luc_Godard', 'Jean-Luc Godard', 1),
#  ('Agent', 'Jean-Luc_Godard', 'Jean-Luc Godard', 1),
#  ('Person', 'Frank_Capra', 'Frank Capra', 1),
#  ('Agent', 'Frank_Capra', 'Frank Capra', 1),
#  ('Person', 'Frank_Capra_Jr.', 'Frank Capra', 2),
#  ('Agent', 'Frank_Capra_Jr.', 'Frank Capra', 2),
#  ('Person', 'Billy_Wilder', 'Billy Wilder', 1),
#  ('Agent', 'Billy_Wilder', 'Billy Wilder', 1),
#  ('Person', 'Spike_Lee', 'Spike Lee', 1),
#  ('Agent', 'Spike_Lee', 'Spike Lee', 1),
#  ('Person', 'Coen_brothers', 'Joel Coen', 1),
#  ('Agent', 'Coen_brothers', 'Joel Coen', 1),
#  ('Person', 'Vittorio_De_Sica', 'Vittorio De Sica', 1),
#  ('Agent', 'Vittorio_De_Sica', 'Vittorio De Sica', 1),
#  ('Person', 'Charles_Laughton', 'Charles Laughton', 1),
#  ('Agent', 'Charles_Laughton', 'Charles Laughton', 1),
#  ('Person', 'John_Huston', 'John Huston', 1),
#  ('Agent', 'John_Huston', 'John Huston', 1),
#  ('Politician', 'John_Hutton,_Baron_Hutton_of_Furness', 'John Huston', 2),
#  ('Person', 'John_Hutton,_Baron_Hutton_of_Furness', 'John Huston', 2),
#  ('Agent', 'John_Hutton,_Baron_Hutton_of_Furness', 'John Huston', 2),
#  ('Person', 'Harold_Ramis', 'Harold Ramis', 1),
#  ('Agent', 'Harold_Ramis', 'Harold Ramis', 1),
#  ('Person', 'Sidney_Lumet', 'Sidney Lumet', 1),
#  ('Agent', 'Sidney_Lumet', 'Sidney Lumet', 1),
#  ('Person', 'Sidney_J._Furie', 'Sidney Lumet', 2),
#  ('Agent', 'Sidney_J._Furie', 'Sidney Lumet', 2),
#  ('Person', 'Thelma_Connell', 'Sidney Lumet', 3),
#  ('Agent', 'Thelma_Connell', 'Sidney Lumet', 3),
#  ('Person', 'Ingmar_Bergman', 'Ingmar Bergman', 1),
#  ('Agent', 'Ingmar_Bergman', 'Ingmar Bergman', 1),
#  ('Award', 'Ingmar_Bergman_Award', 'Ingmar Bergman', 2),
#  ('Album', 'The_Seduction_of_Ingmar_Bergman', 'Ingmar Bergman', 3),
#  ('MusicalWork', 'The_Seduction_of_Ingmar_Bergman', 'Ingmar Bergman', 3),
#  ('Work', 'The_Seduction_of_Ingmar_Bergman', 'Ingmar Bergman', 3),
#  ('Person', 'Daniel_Boulanger', 'Fran?ois Truffaut', 1),
#  ('Artist', 'Daniel_Boulanger', 'Fran?ois Truffaut', 1),
#  ('Actor', 'Daniel_Boulanger', 'Fran?ois Truffaut', 1),
#  ('Agent', 'Daniel_Boulanger', 'Fran?ois Truffaut', 1),
#  ('Person', 'Akira_Kurosawa', 'Akira Kurosawa', 1),
#  ('Agent', 'Akira_Kurosawa', 'Akira Kurosawa', 1),
#  ('Person', 'Elia_Kazan', 'Elia Kazan', 1),
#  ('Agent', 'Elia_Kazan', 'Elia Kazan', 1),
#  ('Person', 'Gene_Milford', 'Elia Kazan', 2),
#  ('Agent', 'Gene_Milford', 'Elia Kazan', 2),
#  ('Organisation', 'Actors_Studio', 'Elia Kazan', 3),
#  ('Agent', 'Actors_Studio', 'Elia Kazan', 3),
#  ('Person', 'William_Wyler', 'William Wyler', 1),
#  ('Agent', 'William_Wyler', 'William Wyler', 1),
#  ('Politician', 'William_Duncan_Wylie', 'William Wyler', 2),
#  ('Person', 'William_Duncan_Wylie', 'William Wyler', 2),
#  ('MemberOfParliament', 'William_Duncan_Wylie', 'William Wyler', 2),
#  ('Agent', 'William_Duncan_Wylie', 'William Wyler', 2),
#  ('Person', 'Federico_Fellini', 'Federico Fellini', 1),
#  ('Agent', 'Federico_Fellini', 'Federico Fellini', 1),
#  ('Airport', 'Federico_Fellini_International_Airport', 'Federico Fellini', 2),
#  ('Place', 'Federico_Fellini_International_Airport', 'Federico Fellini', 2),
#  ('ArchitecturalStructure',
#   'Federico_Fellini_International_Airport',
#   'Federico Fellini',
#   2),
#  ('Location', 'Federico_Fellini_International_Airport', 'Federico Fellini', 2),
#  ('Infrastructure',
#   'Federico_Fellini_International_Airport',
#   'Federico Fellini',
#   2),
#  ('Film', "Fellini's_Casanova", 'Federico Fellini', 3),
#  ('Work', "Fellini's_Casanova", 'Federico Fellini', 3),
#  ('Person', 'John_Ford', 'John Ford', 1),
#  ('Agent', 'John_Ford', 'John Ford', 1),
#  ('Politician', 'Gerald_Ford', 'John Ford', 2),
#  ('Person', 'Gerald_Ford', 'John Ford', 2),
#  ('Agent', 'Gerald_Ford', 'John Ford', 2),
#  ('Person', 'John_Salmon_Ford', 'John Ford', 3),
#  ('MilitaryPerson', 'John_Salmon_Ford', 'John Ford', 3),
#  ('Agent', 'John_Salmon_Ford', 'John Ford', 3),
#  ('Person', 'Quentin_Tarantino', 'Quentin Tarantino', 1),
#  ('Agent', 'Quentin_Tarantino', 'Quentin Tarantino', 1),
#  ('FilmFestival', 'Quentin_Tarantino_Film_Festival', 'Quentin Tarantino', 3),
#  ('Event', 'Quentin_Tarantino_Film_Festival', 'Quentin Tarantino', 3),
#  ('SocietalEvent', 'Quentin_Tarantino_Film_Festival', 'Quentin Tarantino', 3),
#  ('Person', 'Charlie_Chaplin', 'Charles Chaplin', 1),
#  ('Agent', 'Charlie_Chaplin', 'Charles Chaplin', 1),
#  ('Person', 'Charles_Chaplin_Jr.', 'Charles Chaplin', 2),
#  ('Agent', 'Charles_Chaplin_Jr.', 'Charles Chaplin', 2),
#  ('Person', 'Charles_Chaplin_Sr.', 'Charles Chaplin', 3),
#  ('Agent', 'Charles_Chaplin_Sr.', 'Charles Chaplin', 3),
#  ('Person', 'Fred_Zinnemann', 'Fred Zinnemann', 1),
#  ('Agent', 'Fred_Zinnemann', 'Fred Zinnemann', 1),
#  ('Person', 'Jerome_Robbins', 'Jerome Robbins and Robert Wise', 1),
#  ('Agent', 'Jerome_Robbins', 'Jerome Robbins and Robert Wise', 1),
#  ('Person', 'Francis_Ford_Coppola', 'Francis Ford Coppola', 1),
#  ('Agent', 'Francis_Ford_Coppola', 'Francis Ford Coppola', 1),
#  ('Person', 'Mel_Brooks', 'Mel Brooks', 1),
#  ('Agent', 'Mel_Brooks', 'Mel Brooks', 1),
#  ('Musical', 'The_Producers_(musical)', 'Mel Brooks', 3),
#  ('MusicalWork', 'The_Producers_(musical)', 'Mel Brooks', 3),
#  ('Work', 'The_Producers_(musical)', 'Mel Brooks', 3),
#  ('Person', 'Terry_Jones', 'Terry Jones', 1),
#  ('Agent', 'Terry_Jones', 'Terry Jones', 1),
#  ('Person', 'Terry_Jones_(pastor)', 'Terry Jones', 2),
#  ('Religious', 'Terry_Jones_(pastor)', 'Terry Jones', 2),
#  ('Agent', 'Terry_Jones_(pastor)', 'Terry Jones', 2),
#  ('Person', 'Tim_Burton', 'Tim Burton', 1),
#  ('Writer', 'Tim_Burton', 'Tim Burton', 1),
#  ('Agent', 'Tim_Burton', 'Tim Burton', 1),
#  ('Person', 'George_Roy_Hill', 'George Roy Hill', 1),
#  ('Agent', 'George_Roy_Hill', 'George Roy Hill', 1),
#  ('Settlement', 'School_District_57_Prince_George', 'George Roy Hill', 2),
#  ('Place', 'School_District_57_Prince_George', 'George Roy Hill', 2),
#  ('PopulatedPlace', 'School_District_57_Prince_George', 'George Roy Hill', 2),
#  ('Location', 'School_District_57_Prince_George', 'George Roy Hill', 2),
#  ('Person', 'Brian_De_Palma', 'Brian De Palma', 1),
#  ('Agent', 'Brian_De_Palma', 'Brian De Palma', 1),
#  ('Person', 'Kevin_Smith', 'Kevin Smith', 1),
#  ('Agent', 'Kevin_Smith', 'Kevin Smith', 1),
#  ('Politician', 'Robert_Smith,_Baron_Smith_of_Kelvin', 'Kevin Smith', 2),
#  ('Person', 'Robert_Smith,_Baron_Smith_of_Kelvin', 'Kevin Smith', 2),
#  ('Agent', 'Robert_Smith,_Baron_Smith_of_Kelvin', 'Kevin Smith', 2),
#  ('TelevisionShow',
#   'Sold_Out:_A_Threevening_with_Kevin_Smith',
#   'Kevin Smith',
#   3),
#  ('Work', 'Sold_Out:_A_Threevening_with_Kevin_Smith', 'Kevin Smith', 3),
#  ('Person', 'Luc_Besson', 'Luc Besson', 1),
#  ('Agent', 'Luc_Besson', 'Luc Besson', 1),
#  ('Person', 'Peter_Weir', 'Peter Weir', 1),
#  ('Agent', 'Peter_Weir', 'Peter Weir', 1),
#  ('Person', 'Peter_Weir_(footballer)', 'Peter Weir', 3),
#  ('Athlete', 'Peter_Weir_(footballer)', 'Peter Weir', 3),
#  ('SoccerPlayer', 'Peter_Weir_(footballer)', 'Peter Weir', 3),
#  ('Agent', 'Peter_Weir_(footballer)', 'Peter Weir', 3),
#  ('Person', 'Gus_Van_Sant', 'Gus Van Sant', 1),
#  ('Agent', 'Gus_Van_Sant', 'Gus Van Sant', 1),
#  ('Person', 'Darren_Aronofsky', 'Darren Aronofsky', 1),
#  ('Agent', 'Darren_Aronofsky', 'Darren Aronofsky', 1),
#  ('MusicalArtist', 'Clint_Mansell', 'Darren Aronofsky', 3),
#  ('Person', 'Clint_Mansell', 'Darren Aronofsky', 3),
#  ('Artist', 'Clint_Mansell', 'Darren Aronofsky', 3),
#  ('Agent', 'Clint_Mansell', 'Darren Aronofsky', 3),
#  ('Person', 'Rob_Reiner', 'Rob Reiner', 1),
#  ('Agent', 'Rob_Reiner', 'Rob Reiner', 1),
#  ('Band', 'Anvil_(band)', 'Rob Reiner', 2),
#  ('Organisation', 'Anvil_(band)', 'Rob Reiner', 2),
#  ('Agent', 'Anvil_(band)', 'Rob Reiner', 2),
#  ('Group', 'Anvil_(band)', 'Rob Reiner', 2),
#  ('Politician', 'Rob_Renner', 'Rob Reiner', 3),
#  ('Person', 'Rob_Renner', 'Rob Reiner', 3),
#  ('Agent', 'Rob_Renner', 'Rob Reiner', 3),
#  ('Person', 'Edward_Zwick', 'Edward Zwick', 1),
#  ('Agent', 'Edward_Zwick', 'Edward Zwick', 1),
#  ('Person', 'Paul_Thomas_Anderson', 'Paul Thomas Anderson', 1),
#  ('Agent', 'Paul_Thomas_Anderson', 'Paul Thomas Anderson', 1),
#  ('Organisation', 'Miss_Trinidad_and_Tobago', 'Paul Thomas Anderson', 3),
#  ('Agent', 'Miss_Trinidad_and_Tobago', 'Paul Thomas Anderson', 3),
#  ('Person', 'John_Hughes_(filmmaker)', 'John Hughes', 1),
#  ('Agent', 'John_Hughes_(filmmaker)', 'John Hughes', 1),
#  ('Person', 'John_Hughes_(theologian)', 'John Hughes', 3),
#  ('Cleric', 'John_Hughes_(theologian)', 'John Hughes', 3),
#  ('Agent', 'John_Hughes_(theologian)', 'John Hughes', 3),
#  ('MusicalArtist', 'Tony_Kaye_(musician)', 'Tony Kaye', 2),
#  ('Person', 'Tony_Kaye_(musician)', 'Tony Kaye', 2),
#  ('Artist', 'Tony_Kaye_(musician)', 'Tony Kaye', 2),
#  ('Agent', 'Tony_Kaye_(musician)', 'Tony Kaye', 2),
#  ('Person', 'Tony_Kaye_(director)', 'Tony Kaye', 3),
#  ('Agent', 'Tony_Kaye_(director)', 'Tony Kaye', 3),
#  ('Person', 'Barry_Levinson', 'Barry Levinson', 1),
#  ('Agent', 'Barry_Levinson', 'Barry Levinson', 1),
#  ('MusicalArtist', 'Barry_Levenson', 'Barry Levinson', 3),
#  ('Person', 'Barry_Levenson', 'Barry Levinson', 3),
#  ('Artist', 'Barry_Levenson', 'Barry Levinson', 3),
#  ('Agent', 'Barry_Levenson', 'Barry Levinson', 3),
#  ('Person', 'Richmond_K._Turner', 'Richard Kelly', 3),
#  ('MilitaryPerson', 'Richmond_K._Turner', 'Richard Kelly', 3),
#  ('Agent', 'Richmond_K._Turner', 'Richard Kelly', 3),
#  ('Person', 'William_Friedkin', 'William Friedkin', 1),
#  ('Agent', 'William_Friedkin', 'William Friedkin', 1),
#  ('Person', 'William_F._Friedman', 'William Friedkin', 2),
#  ('Engineer', 'William_F._Friedman', 'William Friedkin', 2),
#  ('Agent', 'William_F._Friedman', 'William Friedkin', 2),
#  ('Person', 'Jean-Pierre_Jeunet', 'Jean-Pierre Jeunet', 1),
#  ('Agent', 'Jean-Pierre_Jeunet', 'Jean-Pierre Jeunet', 1),
#  ('Person', 'Sergio_Leone', 'Sergio Leone', 1),
#  ('Agent', 'Sergio_Leone', 'Sergio Leone', 1),
#  ('Person', 'Sergio_Agüero', 'Sergio Leone', 2),
#  ('Athlete', 'Sergio_Agüero', 'Sergio Leone', 2),
#  ('SoccerPlayer', 'Sergio_Agüero', 'Sergio Leone', 2),
#  ('Agent', 'Sergio_Agüero', 'Sergio Leone', 2),
#  ('Person', 'Fernando_Meirelles', 'Fernando Meirelles', 1),
#  ('Agent', 'Fernando_Meirelles', 'Fernando Meirelles', 1),
#  ('Organisation', 'Club_Sport_Colombia', 'Fernando Meirelles', 3),
#  ('SoccerClub', 'Club_Sport_Colombia', 'Fernando Meirelles', 3),
#  ('Agent', 'Club_Sport_Colombia', 'Fernando Meirelles', 3),
#  ('SportsClub', 'Club_Sport_Colombia', 'Fernando Meirelles', 3),
#  ('Person', 'Franklin_J._Schaffner', 'Franklin J. Schaffner', 1),
#  ('Agent', 'Franklin_J._Schaffner', 'Franklin J. Schaffner', 1),
#  ('Person', 'Fred_J._Koenekamp', 'Franklin J. Schaffner', 3),
#  ('Agent', 'Fred_J._Koenekamp', 'Franklin J. Schaffner', 3),
#  ('Organisation',
#   'Zucker,_Abrahams_and_Zucker',
#   'Jerry Zucker, Jim Abrahams, and David Zucker',
#   1),
#  ('ComedyGroup',
#   'Zucker,_Abrahams_and_Zucker',
#   'Jerry Zucker, Jim Abrahams, and David Zucker',
#   1),
#  ('Agent',
#   'Zucker,_Abrahams_and_Zucker',
#   'Jerry Zucker, Jim Abrahams, and David Zucker',
#   1),
#  ('Group',
#   'Zucker,_Abrahams_and_Zucker',
#   'Jerry Zucker, Jim Abrahams, and David Zucker',
#   1),
#  ('Person', 'Wolfgang_Petersen', 'Wolfgang Petersen', 1),
#  ('Agent', 'Wolfgang_Petersen', 'Wolfgang Petersen', 1),
#  ('Person', 'Wolfgang_Peters', 'Wolfgang Petersen', 2),
#  ('Athlete', 'Wolfgang_Peters', 'Wolfgang Petersen', 2),
#  ('SoccerPlayer', 'Wolfgang_Peters', 'Wolfgang Petersen', 2),
#  ('Agent', 'Wolfgang_Peters', 'Wolfgang Petersen', 2),
#  ('Person', 'Wolfgang_Peters_(canoeist)', 'Wolfgang Petersen', 3),
#  ('Athlete', 'Wolfgang_Peters_(canoeist)', 'Wolfgang Petersen', 3),
#  ('Canoeist', 'Wolfgang_Peters_(canoeist)', 'Wolfgang Petersen', 3),
#  ('Agent', 'Wolfgang_Peters_(canoeist)', 'Wolfgang Petersen', 3),
#  ('Person', 'Gary_Trousdale', 'Gary Trousdale and Kirk Wise', 2),
#  ('Agent', 'Gary_Trousdale', 'Gary Trousdale and Kirk Wise', 2),
#  ('Person', 'Phil_Alden_Robinson', 'Phil Alden Robinson', 1),
#  ('Agent', 'Phil_Alden_Robinson', 'Phil Alden Robinson', 1),
#  ('Person', 'John_Sturges', 'John Sturges', 1),
#  ('Agent', 'John_Sturges', 'John Sturges', 1),
#  ('Person', 'John_Hubbard_Sturgis', 'John Sturges', 3),
#  ('Architect', 'John_Hubbard_Sturgis', 'John Sturges', 3),
#  ('Agent', 'John_Hubbard_Sturgis', 'John Sturges', 3),
#  ('Person', 'Roberto_Benigni', 'Roberto Benigni', 1),
#  ('Agent', 'Roberto_Benigni', 'Roberto Benigni', 1),
#  ('Person', 'Baz_Luhrmann', 'Baz Luhrmann', 1),
#  ('Agent', 'Baz_Luhrmann', 'Baz Luhrmann', 1),
#  ('Album',
#   "The_Great_Gatsby:_Music_from_Baz_Luhrmann's_Film",
#   'Baz Luhrmann',
#   3),
#  ('MusicalWork',
#   "The_Great_Gatsby:_Music_from_Baz_Luhrmann's_Film",
#   'Baz Luhrmann',
#   3),
#  ('Work',
#   "The_Great_Gatsby:_Music_from_Baz_Luhrmann's_Film",
#   'Baz Luhrmann',
#   3),
#  ('Person', 'George_Cukor', 'George Cukor', 1),
#  ('Agent', 'George_Cukor', 'George Cukor', 1),
#  ('Person', 'Arthur_Roberts_(editor)', 'George Cukor', 3),
#  ('Agent', 'Arthur_Roberts_(editor)', 'George Cukor', 3),
#  ('Person', 'Leo_McCarey', 'Leo McCarey', 1),
#  ('Agent', 'Leo_McCarey', 'Leo McCarey', 1),
#  ('Politician', 'Leo_T._McCarthy', 'Leo McCarey', 2),
#  ('Person', 'Leo_T._McCarthy', 'Leo McCarey', 2),
#  ('Agent', 'Leo_T._McCarthy', 'Leo McCarey', 2),
#  ('Person', 'Kevin_Costner', 'Kevin Costner', 1),
#  ('Agent', 'Kevin_Costner', 'Kevin Costner', 1),
#  ('Band', 'Kevin_Costner_&_Modern_West', 'Kevin Costner', 2),
#  ('Organisation', 'Kevin_Costner_&_Modern_West', 'Kevin Costner', 2),
#  ('Agent', 'Kevin_Costner_&_Modern_West', 'Kevin Costner', 2),
#  ('Group', 'Kevin_Costner_&_Modern_West', 'Kevin Costner', 2),
#  ('Person', 'Andrew_Davis_(director)', 'Andrew Davis', 1),
#  ('Agent', 'Andrew_Davis_(director)', 'Andrew Davis', 1),
#  ('Person', 'Andrew_Davies_(writer)', 'Andrew Davis', 2),
#  ('Writer', 'Andrew_Davies_(writer)', 'Andrew Davis', 2),
#  ('Agent', 'Andrew_Davies_(writer)', 'Andrew Davis', 2),
#  ('Person', 'George_Andrew_Davis_Jr.', 'Andrew Davis', 3),
#  ('MilitaryPerson', 'George_Andrew_Davis_Jr.', 'Andrew Davis', 3),
#  ('Agent', 'George_Andrew_Davis_Jr.', 'Andrew Davis', 3),
#  ('Person', 'Ang_Lee', 'Ang Lee', 1),
#  ('Agent', 'Ang_Lee', 'Ang Lee', 1),
#  ('MusicalArtist', 'Lee_Ann_Womack', 'Ang Lee', 2),
#  ('Person', 'Lee_Ann_Womack', 'Ang Lee', 2),
#  ('Artist', 'Lee_Ann_Womack', 'Ang Lee', 2),
#  ('Agent', 'Lee_Ann_Womack', 'Ang Lee', 2),
#  ('Person', 'Angelica_Lee', 'Ang Lee', 3),
#  ('Agent', 'Angelica_Lee', 'Ang Lee', 3),
#  ('Person', 'Fritz_Lang', 'Fritz Lang', 1),
#  ('Agent', 'Fritz_Lang', 'Fritz Lang', 1),
#  ('Person', 'David_Lynch', 'David Lynch', 1),
#  ('Agent', 'David_Lynch', 'David Lynch', 1),
#  ('Band', 'The_Platters', 'David Lynch', 3),
#  ('Organisation', 'The_Platters', 'David Lynch', 3),
#  ('Agent', 'The_Platters', 'David Lynch', 3),
#  ('Group', 'The_Platters', 'David Lynch', 3),
#  ('Person', 'Clyde_Bruckman', 'Clyde Bruckman and Buster Keaton', 1),
#  ('Agent', 'Clyde_Bruckman', 'Clyde Bruckman and Buster Keaton', 1),
#  ('Person', 'Carl_Theodor_Dreyer', 'Carl Theodor Dreyer', 1),
#  ('Agent', 'Carl_Theodor_Dreyer', 'Carl Theodor Dreyer', 1),
#  ('Person', 'Edith_Schlüssel', 'Carl Theodor Dreyer', 3),
#  ('Agent', 'Edith_Schlüssel', 'Carl Theodor Dreyer', 3),
#  ('Person',
#   'Ernest_B._Schoedsack',
#   'Merian C. Cooper and Ernest B. Schoedsack',
#   1),
#  ('Agent',
#   'Ernest_B._Schoedsack',
#   'Merian C. Cooper and Ernest B. Schoedsack',
#   1),
#  ('Person', 'Spike_Jonze', 'Spike Jonze', 1),
#  ('Agent', 'Spike_Jonze', 'Spike Jonze', 1),
#  ('TelevisionShow',
#   'The_Increasingly_Poor_Decisions_of_Todd_Margaret',
#   'Spike Jonze',
#   3),
#  ('Work',
#   'The_Increasingly_Poor_Decisions_of_Todd_Margaret',
#   'Spike Jonze',
#   3),
#  ('Person', 'Stuart_Rosenberg', 'Stuart Rosenberg', 1),
#  ('Agent', 'Stuart_Rosenberg', 'Stuart Rosenberg', 1),
#  ('Settlement', 'Roseburg,_Oregon', 'Stuart Rosenberg', 2),
#  ('City', 'Roseburg,_Oregon', 'Stuart Rosenberg', 2),
#  ('Place', 'Roseburg,_Oregon', 'Stuart Rosenberg', 2),
#  ('PopulatedPlace', 'Roseburg,_Oregon', 'Stuart Rosenberg', 2),
#  ('Location', 'Roseburg,_Oregon', 'Stuart Rosenberg', 2),
#  ('Person', 'Ivan_Reitman', 'Ivan Reitman', 1),
#  ('Agent', 'Ivan_Reitman', 'Ivan Reitman', 1),
#  ('Person', 'Ivan_Reimann', 'Ivan Reitman', 2),
#  ('Athlete', 'Ivan_Reimann', 'Ivan Reitman', 2),
#  ('SoccerPlayer', 'Ivan_Reimann', 'Ivan Reitman', 2),
#  ('Agent', 'Ivan_Reimann', 'Ivan Reitman', 2),
#  ('Person', 'Tom_Tykwer', 'Tom Tykwer', 1),
#  ('Agent', 'Tom_Tykwer', 'Tom Tykwer', 1),
#  ('Person', 'Tom_Tyler', 'Tom Tykwer', 2),
#  ('Agent', 'Tom_Tyler', 'Tom Tykwer', 2),
#  ('Band', 'Symphony_X', 'Tom Tykwer', 3),
#  ('Organisation', 'Symphony_X', 'Tom Tykwer', 3),
#  ('Agent', 'Symphony_X', 'Tom Tykwer', 3),
#  ('Group', 'Symphony_X', 'Tom Tykwer', 3),
#  ('Person', 'Cameron_Crowe', 'Cameron Crowe', 1),
#  ('Agent', 'Cameron_Crowe', 'Cameron Crowe', 1),
#  ('Person', 'John_Carpenter', 'John Carpenter', 1),
#  ('Agent', 'John_Carpenter', 'John Carpenter', 1),
#  ('Politician',
#   'John_Boyd-Carpenter,_Baron_Boyd-Carpenter',
#   'John Carpenter',
#   2),
#  ('Person', 'John_Boyd-Carpenter,_Baron_Boyd-Carpenter', 'John Carpenter', 2),
#  ('Agent', 'John_Boyd-Carpenter,_Baron_Boyd-Carpenter', 'John Carpenter', 2)]

# %%
candidate_classes = list([])
candidate_classes_rank = list([])
for key in entity_classes:
    for candicate_class in entity_classes[key]:
        cc,rank = candicate_class
        if cc not in candidate_classes:
            candidate_classes.append(cc)
            candidate_classes_rank.append((cc,rank))

candidate_classes_rank = sorted(candidate_classes_rank, key=lambda x: x[1])
[t[0] for t in candidate_classes_rank if t[1]<=3]
# Out:
# ['AdministrativeRegion',
#  'Place',
#  'PopulatedPlace',
#  'Location',
#  'Region',
#  'Settlement',
#  'Town',
#  'HistoricPlace',
#  'Criminal',
#  'Person',
#  'SportsTeam',
#  'AmericanFootballTeam',
#  'Building',
#  'ArchitecturalStructure',
#  'Village',
#  'River',
#  'Stream',
#  'Lake',
#  'Organisation',
#  'School',
#  'EducationalInstitution',
#  'Agent',
#  'SoccerLeague',
#  'SportsLeague',
#  'SoccerClub',
#  'SportsClub',
#  'Politician']

# %%
spark = SparkSession.builder.appName('Annotation').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LPT3966.bjss.co.uk:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Annotation</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.option('header','True').csv('CTRL_DBP_GEO_us_lakes.csv')

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- lake: string (nullable = true)
#  |-- area: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- state: string (nullable = true)

# %%
type(df_pyspark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e08d6c608363> in <module>
# ----> 1 type(df_pyspark)
#
# NameError: name 'df_pyspark' is not defined
